# %% [markdown]
# # RAG Evaluation Test Set Generation
#
# This example shows how to use the [Ragas](https://github.com/explodinggradients/ragas) framework to generate a **test set** that can be used to evaluate the quality of a RAG pipeline. We then use the Python [langchain](https://python.langchain.com/docs/get_started/introduction) library to run some requests through this pipeline and we evaluate the quality of the results.
#
# **Requirements:**
# - You will need an access key to OpenAI's API key, which you can sign up for at (https://dashboard.cohere.com/welcome/login). A free trial account will suffice, but will be limited to a small number of requests.
# - After obtaining this key, store it in plain text in your home in directory in the `~/.openai.key` file.
# - (Optional) Upload some pdf files into the `source_documents` subfolder under this notebook. We have already provided some sample pdfs, but feel free to replace these with your own.

# %% [markdown]
# ## Set up the RAG workflow environment

# %%
from datasets import Dataset 
from getpass import getpass
from langchain.chains import RetrievalQA
from langchain.document_loaders.pdf import PyPDFDirectoryLoader
from langchain.retrievers import ContextualCompressionRetriever
from langchain.retrievers.document_compressors import EmbeddingsFilter
from langchain.schema import HumanMessage
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain_openai import ChatOpenAI, OpenAIEmbeddings
from langchain_community.vectorstores import FAISS
import numpy as np
import os
from pathlib import Path

from ragas import evaluate
from ragas.metrics import faithfulness, answer_correctness, context_precision
from ragas.testset.generator import TestsetGenerator
from ragas.testset.evolutions import simple, reasoning, multi_context

# %% [markdown]
# Set up some helper functions:

# %%
def pretty_print_docs(docs):
    print(
        f"\n{'-' * 100}\n".join(
            [f"Document {i+1}:\n\n" + d.page_content for i, d in enumerate(docs)]
        )
    )

# %% [markdown]
# Make sure other necessary items are in place:

# %%
try:
    os.environ["OPENAI_API_KEY"] = open(Path.home() / ".openai.key", "r").read().strip()
except Exception as err:
    print(f"Could not read your OpenAI key. Please make sure this is available in plain text under your home directory in ~/.openai.key: {err}")

# Look for the source_documents folder and make sure there is at least 1 pdf file here
contains_pdf = False
documents_path = "./source_documents"
if not os.path.exists(documents_path):
    print(f"ERROR: The {documents_path} subfolder must exist under this notebook")
for filename in os.listdir(documents_path):
    contains_pdf = True if ".pdf" in filename else contains_pdf
if not contains_pdf:
    print(f"ERROR: The {documents_path} subfolder must contain at least one .pdf file")

# %% [markdown]
# ## Generate a sythentic test set

# %% [markdown]
# Start by loading in the documents we'll be using to augment our RAG generations

# %%
loader = PyPDFDirectoryLoader(documents_path)
documents = loader.load()
for document in documents:
    document.metadata['file_name'] = document.metadata['source']

# %% [markdown]
# Now use OpenAI to generate a test set from the data in these documents

# %%
# Create generator with openai models
generator = TestsetGenerator.with_openai()

# Generate the testset
testset = generator.generate_with_langchain_docs(
    documents, 
    test_size=10, 
    distributions={simple: 0.5, reasoning: 0.25, multi_context: 0.25}
)
# Out:
# embedding nodes:   0%|          | 0/118 [00:00<?, ?it/s]
# Generating:   0%|          | 0/10 [00:00<?, ?it/s]

# %% [markdown]
# Preview the test dataset so far

# %%
testset.to_pandas()
# Out:
#                                             question  \
# 0  What is the mission of the Vector Institute an...
# 1  How does Vector aim to ensure safe and secure ...
# 2  What is the purpose of Vector's annual AI Summ...
# 3  How did the addition of full-time AI Engineeri...
# 4  What skills did participants gain in the Vecto...
# 5  Who provides funding for the Vector Institute ...
# 6  How does Vector's leading work in making healt...
# 7  "What is the Vector Institute's mission in dee...
# 8  How does Vector's approach to data governance ...
# 9  How does the Vector Institute contribute to AI...
#
#                                             contexts  \
# 0  [4 \nAnnual Report 2021–22 Vector Institute\n ...
# 1  [ in Vector’s leading work \nin making health ...
# 2  [28 \n MAKING CAREER \nCONNECTIONS FASTER WITH...
# 3  [36 \n \n \n  CREATING IMPACT \nTHROUGH APPLIC...
# 4  [37 \nAnnual Report 2021–22 Vector Institute\n...
# 5  [4 \nAnnual Report 2021–22 Vector Institute\n ...
# 6  [ in Vector’s leading work \nin making health ...
# 7  [4 \nAnnual Report 2021–22 Vector Institute\n ...
# 8  [ in Vector’s leading work \nin making health ...
# 9  [4 \nAnnual Report 2021–22 Vector Institute\n ...
#
#                                         ground_truth evolution_type  \
# 0  The mission of the Vector Institute is to lead...         simple
# 1  Vector aims to ensure safe and secure research...         simple
# 2  The purpose of Vector's annual AI Summit and C...         simple
# 3  The addition of full-time AI Engineering resou...         simple
# 4  Participants in the Vector bootcamp gained new...         simple
# 5  The Vector Institute is funded by the Governme...      reasoning
# 6  Vector's leading work in making health data mo...      reasoning
# 7  The Vector Institute's mission is to lead Onta...  multi_context
# 8  Vector's approach to data governance contribut...  multi_context
# 9  The Vector Institute contributes to AI-based i...      reasoning
#
#    episode_done
# 0          True
# 1          True
# 2          True
# 3          True
# 4          True
# 5          True
# 6          True
# 7          True
# 8          True
# 9          True

# %% [markdown]
# # Now, start the RAG pipeline!

# %% [markdown]
# ## Generate answers for all the questions in our test set

# %% [markdown]
# Go through the embedding, storage and retrieval steps.

# %%
# Split the documents into smaller chunks
text_splitter = RecursiveCharacterTextSplitter(chunk_size=250, chunk_overlap=100)
chunks = text_splitter.split_documents(documents)
print(f"Number of text chunks: {len(chunks)}")

# Define the embeddings model
model_name = "BAAI/bge-small-en-v1.5"
encode_kwargs = {'normalize_embeddings': True} # set True to compute cosine similarity

print(f"Setting up the embeddings model...")
embeddings = OpenAIEmbeddings(model="text-embedding-ada-002")
# Out:
# Number of text chunks: 569
# Setting up the embeddings model...

# %% [markdown]
# Iterate over the questions in our synthetic testset, and run them each through the RAG pipeline to see what answers get returned.

# %%
dataset = testset.to_dataset()
answers = np.empty(len(dataset), dtype=object)
llm = ChatOpenAI()

for index, row in enumerate(dataset):
    query = row["question"]
    
    # Retrieve the most relevant context from the vector store based on the query
    vectorstore = FAISS.from_documents(chunks, embeddings)
    retriever = vectorstore.as_retriever(search_kwargs={"k": 20})
    
    # Run the query via our llm (OpenAI) without reranking
    qa = RetrievalQA.from_chain_type(llm=llm,
            chain_type="stuff",
            retriever=retriever)
    answer = qa.run(query=query)
    print(f"Result {index}\nQuestion: {query}\nAnswer: {answer}\n")
   
    # Store the result
    answers[index] = answer
    
    # Let's skip the reranking in this example to keep it fast.
    # Uncomment the following lines to see how reranking will affect the results.
    """
    embeddings = OpenAIEmbeddings()
    embeddings_filter = EmbeddingsFilter(embeddings=embeddings, similarity_threshold=0.76)
    compression_retriever = ContextualCompressionRetriever(
        base_compressor=embeddings_filter, base_retriever=retriever
    )
    compressed_docs = compression_retriever.get_relevant_documents(query)
    
    answer = RetrievalQA.from_chain_type(llm=llm,
        chain_type="stuff",
        retriever=compression_retriever)
        
    dataset[index]["answer"]["answer"] = answer
    print(f"Result:\nQuestion: {query}\nAnswer: {qa.run(query=query)}\n")
    """
# Out:
# /fs01/projects/aieng/public/rag_bootcamp/envs/rag_evaluation/lib/python3.10/site-packages/langchain_core/_api/deprecation.py:117: LangChainDeprecationWarning: The function `run` was deprecated in LangChain 0.1.0 and will be removed in 0.2.0. Use invoke instead.
#   warn_deprecated(
# Result 0
# Question: What is the mission of the Vector Institute and how does it relate to deep learning and machine learning?
# Answer: The mission of the Vector Institute is to drive excellence and leadership in Canada's knowledge, creation, and use of AI to foster economic growth and improve the lives of Canadians. The institute is focused on advancing the frontiers of AI knowledge through research, education, and engineering new applications of AI in various industries. They work with a team of applied machine learning experts to push the boundaries of AI innovation and provide learning opportunities for students, postdoctoral fellows, and recent graduates in machine learning and deep learning. Additionally, Vector Institute is committed to developing programming for Black and Indigenous students to expand career pathways in AI for historically underrepresented groups, aiming towards greater inclusion in the field of AI.
#
# Result 1
# Question: How does Vector aim to ensure safe and secure research and application of health data in Canada, particularly in relation to the integration of AI across sectors?
# Answer: Vector aims to ensure safe and secure research and application of health data in Canada by engaging with partners in the health and academic sectors to enable effective, safe, and secure research access to Ontario’s diverse health data. They provide learning research expertise to help health partners apply AI to reduce costs, improve patient-centered care, and refine clinical outcomes. Additionally, Vector develops frameworks to improve access to data for AI with a focus on security, privacy, and confidentiality. They also help Ontario hospitals adopt machine learning applications and partner on health data initiatives to ensure the appropriate adoption of AI in healthcare.
#
# Result 2
# Question: What is the purpose of Vector's annual AI Summit and Career Fair and what are some of the highlights from this year's event?
# Answer: The purpose of Vector's annual AI Summit and Career Fair is to bring together the Vector research community, top AI researchers, clinicians, and teams from leading employers to share cutting-edge work, build collaborations, and provide networking opportunities.
#
# Some highlights from this year's event include participants gaining insights from industry and research leaders, developing AI use cases, receiving guidance on deploying AI solutions, exploring the implications of AI for business, policy, and ethics, showcasing emerging issues in applied AI, and providing career support sessions and webinars for students. Additionally, the event facilitated connections between top employers and AI-skilled talent through the Digital Talent Hub, career fairs, and development programming.
#
# Result 3
# Question: How did the addition of full-time AI Engineering resources impact Vector's ability to support industry, health, and government partners in solving AI deployment engineering challenges?
# Answer: The addition of new full-time AI Engineering resources at Vector has enabled more of Vector's industry, health, and government partners to access deep expertise and direct guidance in solving AI deployment engineering challenges. This has allowed for more direct, case-specific support to address real-world AI challenges faced by these organizations, ultimately accelerating AI deployment and driving business value for the partners.
#
# Result 4
# Question: What skills did participants gain in the Vector bootcamp regarding Privacy Enhancing Technologies (PETs) and how are these technologies important for working with sensitive data?
# Answer: Participants in the Vector bootcamp on Privacy Enhancing Technologies (PETs) gained skills in various techniques such as differential privacy, homomorphic encryption, and multi-party computation. These skills are crucial for working with sensitive data because they help ensure privacy and confidentiality while utilizing the power of machine and deep learning. By learning these PETs, participants can build secure models and prototypes to protect sensitive data in industries like finance, healthcare, industry sectors, and government, where data privacy is paramount.
#
# Result 5
# Question: Who provides funding for the Vector Institute and what is their objective in terms of AI innovation and growth in Canada?
# Answer: The Vector Institute is funded by the Government of Canada, the Government of Ontario, as well as industry sponsors from across the Canadian economy. Their objective is to drive excellence and leadership in Canada’s knowledge, creation, and use of AI to foster economic growth and improve the lives of Canadians. They aim to develop AI commercialization programming and activities to support AI innovation and growth in Canada.
#
# Result 6
# Question: How does Vector's leading work in making health data more accessible contribute to the development and implementation of practical and enforceable frameworks for data storage, protection, and access in order to enable the development and scaling of innovative technologies and data-driven insights for improved outcomes in Canada?
# Answer: Vector's leading work in making health data more accessible contributes to the development and implementation of practical and enforceable frameworks for data storage, protection, and access by engaging with partners in the health and academic sectors. By collaborating with these partners and utilizing administrative health data available from various sources, Vector is able to lead crucial AI-enabled research across a range of subject areas. This research helps in developing frameworks to guide where and how data are stored and protected, ensuring safe and secure research access to Ontario’s diverse health data. These efforts not only enable the development and scaling of innovative technologies but also contribute data-driven insights to improve outcomes in Canada's health systems.
#
# Result 7
# Question: "What is the Vector Institute's mission in deep learning and machine learning, and how does it contribute to Canada's AI innovation and economic growth?"
# Answer: The Vector Institute's mission in deep learning and machine learning is to lead Ontario's efforts in building and sustaining AI-based innovation, growth, and productivity in Canada. They focus on the transformative potential of deep learning and machine learning. This contributes to Canada's AI innovation and economic growth by providing learning and work experiences in AI to Black and Indigenous talent, developing programming for underrepresented groups, and enabling Canadian enterprises to create business value using AI to compete globally and retain top talent. Additionally, Vector collaborates with industry sponsors and works on advancing technologies and responsible AI to drive excellence and leadership in Canada's AI landscape.
#
# Result 8
# Question: How does Vector's approach to data governance contribute to making health data more accessible for research in Canada, and what initiatives are they taking?
# Answer: Vector's approach to data governance aims to make health data more accessible for safe and secure research in Canada. They have initiatives focused on establishing modern data governance frameworks, policies, and processes to guide the safe use of data. By engaging with partners in the health and academic sectors, Vector enables effective, safe, and secure research access to Ontario’s diverse health data.
#
# Furthermore, Vector collaborates with the Ontario Ministry of Health to derive insights from Ministry data and on data governance considerations. They also participate in the Global Partnership on AI to address priorities such as data governance and responsible AI. These efforts help ensure that high-quality data is accessible for AI-enabled health research, including studies related to important issues like Ontario's COVID-19 pandemic response.
#
# Result 9
# Question: How does the Vector Institute contribute to AI-based innovation in Canada and what is its mission in relation to deep learning and machine learning?
# Answer: The Vector Institute contributes to AI-based innovation in Canada by focusing on developing programming for historically underrepresented groups, such as Black and Indigenous students, postdoctoral fellows, and recent graduates, to build research opportunities and expand career pathways in AI. Additionally, Vector equips Canadian businesses to accelerate AI adoption and drive business value.
#
# In relation to deep learning and machine learning, the Vector Institute's mission is to lead Ontario's efforts to build and sustain AI-based innovation, growth, and productivity in Canada by focusing on the transformative potential of deep learning and machine learning. They also focus on enabling responsible AI, advancing technologies, and building and maintaining Canada's essential machine learning computational infrastructure to enable innovation.

# %% [markdown]
# Add the list of answers into our original dataset. Now we have a complete test set that is ready for evaluation.

# %%
dataset = dataset.add_column("answer", answers)

# %% [markdown]
# ## Evaluate the results

# %%
# Preview the final dataset
dataset.to_pandas()
# Out:
#                                             question  \
# 0  What is the mission of the Vector Institute an...
# 1  How does Vector aim to ensure safe and secure ...
# 2  What is the purpose of Vector's annual AI Summ...
# 3  How did the addition of full-time AI Engineeri...
# 4  What skills did participants gain in the Vecto...
# 5  Who provides funding for the Vector Institute ...
# 6  How does Vector's leading work in making healt...
# 7  "What is the Vector Institute's mission in dee...
# 8  How does Vector's approach to data governance ...
# 9  How does the Vector Institute contribute to AI...
#
#                                             contexts  \
# 0  [4 \nAnnual Report 2021–22 Vector Institute\n ...
# 1  [ in Vector’s leading work \nin making health ...
# 2  [28 \n MAKING CAREER \nCONNECTIONS FASTER WITH...
# 3  [36 \n \n \n  CREATING IMPACT \nTHROUGH APPLIC...
# 4  [37 \nAnnual Report 2021–22 Vector Institute\n...
# 5  [4 \nAnnual Report 2021–22 Vector Institute\n ...
# 6  [ in Vector’s leading work \nin making health ...
# 7  [4 \nAnnual Report 2021–22 Vector Institute\n ...
# 8  [ in Vector’s leading work \nin making health ...
# 9  [4 \nAnnual Report 2021–22 Vector Institute\n ...
#
#                                         ground_truth evolution_type  \
# 0  The mission of the Vector Institute is to lead...         simple
# 1  Vector aims to ensure safe and secure research...         simple
# 2  The purpose of Vector's annual AI Summit and C...         simple
# 3  The addition of full-time AI Engineering resou...         simple
# 4  Participants in the Vector bootcamp gained new...         simple
# 5  The Vector Institute is funded by the Governme...      reasoning
# 6  Vector's leading work in making health data mo...      reasoning
# 7  The Vector Institute's mission is to lead Onta...  multi_context
# 8  Vector's approach to data governance contribut...  multi_context
# 9  The Vector Institute contributes to AI-based i...      reasoning
#
#    episode_done                                             answer
# 0          True  The mission of the Vector Institute is to driv...
# 1          True  Vector aims to ensure safe and secure research...
# 2          True  The purpose of Vector's annual AI Summit and C...
# 3          True  The addition of new full-time AI Engineering r...
# 4          True  Participants in the Vector bootcamp on Privacy...
# 5          True  The Vector Institute is funded by the Governme...
# 6          True  Vector's leading work in making health data mo...
# 7          True  The Vector Institute's mission in deep learnin...
# 8          True  Vector's approach to data governance aims to m...
# 9          True  The Vector Institute contributes to AI-based i...

# %% [markdown]
# Run the evaluation query to score the results. In this evaluation, we are looking at the following metrics:
# - **Faithfulness**: The generated answer is regarded as faithful if all the claims that are made in the answer can be inferred from the given context(s).
# - **Context Precision**: Did our retriever return good results that matched the question it was being asked?
# - **Answer Correctness**: Was the generated answer actually correct? Was it complete?

# %%
score = evaluate(dataset, metrics=[faithfulness,context_precision,answer_correctness])
score.to_pandas()
# Out:
# Evaluating:   0%|          | 0/30 [00:00<?, ?it/s]
#                                             question  \
# 0  What is the mission of the Vector Institute an...
# 1  How does Vector aim to ensure safe and secure ...
# 2  What is the purpose of Vector's annual AI Summ...
# 3  How did the addition of full-time AI Engineeri...
# 4  What skills did participants gain in the Vecto...
# 5  Who provides funding for the Vector Institute ...
# 6  How does Vector's leading work in making healt...
# 7  "What is the Vector Institute's mission in dee...
# 8  How does Vector's approach to data governance ...
# 9  How does the Vector Institute contribute to AI...
#
#                                             contexts  \
# 0  [4 \nAnnual Report 2021–22 Vector Institute\n ...
# 1  [ in Vector’s leading work \nin making health ...
# 2  [28 \n MAKING CAREER \nCONNECTIONS FASTER WITH...
# 3  [36 \n \n \n  CREATING IMPACT \nTHROUGH APPLIC...
# 4  [37 \nAnnual Report 2021–22 Vector Institute\n...
# 5  [4 \nAnnual Report 2021–22 Vector Institute\n ...
# 6  [ in Vector’s leading work \nin making health ...
# 7  [4 \nAnnual Report 2021–22 Vector Institute\n ...
# 8  [ in Vector’s leading work \nin making health ...
# 9  [4 \nAnnual Report 2021–22 Vector Institute\n ...
#
#                                         ground_truth evolution_type  \
# 0  The mission of the Vector Institute is to lead...         simple
# 1  Vector aims to ensure safe and secure research...         simple
# 2  The purpose of Vector's annual AI Summit and C...         simple
# 3  The addition of full-time AI Engineering resou...         simple
# 4  Participants in the Vector bootcamp gained new...         simple
# 5  The Vector Institute is funded by the Governme...      reasoning
# 6  Vector's leading work in making health data mo...      reasoning
# 7  The Vector Institute's mission is to lead Onta...  multi_context
# 8  Vector's approach to data governance contribut...  multi_context
# 9  The Vector Institute contributes to AI-based i...      reasoning
#
#    episode_done                                             answer  \
# 0          True  The mission of the Vector Institute is to driv...
# 1          True  Vector aims to ensure safe and secure research...
# 2          True  The purpose of Vector's annual AI Summit and C...
# 3          True  The addition of new full-time AI Engineering r...
# 4          True  Participants in the Vector bootcamp on Privacy...
# 5          True  The Vector Institute is funded by the Governme...
# 6          True  Vector's leading work in making health data mo...
# 7          True  The Vector Institute's mission in deep learnin...
# 8          True  Vector's approach to data governance aims to m...
# 9          True  The Vector Institute contributes to AI-based i...
#
#    faithfulness  context_precision  answer_correctness
# 0      0.800000                1.0            0.787471
# 1      0.833333                1.0            0.421652
# 2      0.125000                1.0            0.804268
# 3      1.000000                1.0            0.621038
# 4      1.000000                1.0            0.743473
# 5      0.750000                1.0            0.748992
# 6      0.666667                1.0            0.491426
# 7      0.714286                1.0            0.708225
# 8      0.666667                1.0            0.715637
# 9      0.428571                1.0            0.821558
