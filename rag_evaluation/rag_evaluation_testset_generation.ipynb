# %% [markdown]
# # RAG Evaluation Test Set Generation
#
# This example shows how to use the [Ragas](https://github.com/explodinggradients/ragas) framework to generate a **test set** that can be used to evaluate the quality of a RAG pipeline. We then use the Python [langchain](https://python.langchain.com/docs/get_started/introduction) library to run some requests through this pipeline and we evaluate the quality of the results.
#
# **Requirements:**
# - You will need an OpenAI access key, which requires a paid account you can sign up for at https://platform.openai.com/signup.
# - After obtaining this key, store it in plain text in your home in directory in the `~/.openai.key` file.
# - (Optional) Upload some pdf files into the `source_documents` subfolder under this notebook. We have already provided some sample pdfs, but feel free to replace these with your own.

# %% [markdown]
# ## Set up the RAG workflow environment

# %%
from datasets import Dataset 
from getpass import getpass
from langchain.chains import RetrievalQA
from langchain.document_loaders.pdf import PyPDFDirectoryLoader
from langchain.retrievers import ContextualCompressionRetriever
from langchain.retrievers.document_compressors import EmbeddingsFilter
from langchain.schema import HumanMessage
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain_openai import ChatOpenAI, OpenAIEmbeddings
from langchain_community.vectorstores import FAISS
import numpy as np
import os
from pathlib import Path

from ragas import evaluate
from ragas.metrics import faithfulness, answer_correctness, context_precision
from ragas.testset.generator import TestsetGenerator
from ragas.testset.evolutions import simple, reasoning, multi_context

# %% [markdown]
# Set up some helper functions:

# %%
def pretty_print_docs(docs):
    print(
        f"\n{'-' * 100}\n".join(
            [f"Document {i+1}:\n\n" + d.page_content for i, d in enumerate(docs)]
        )
    )

# %% [markdown]
# Make sure other necessary items are in place:

# %%
try:
    os.environ["OPENAI_API_KEY"] = open(Path.home() / ".openai.key", "r").read().strip()
except Exception as err:
    print(f"Could not read your OpenAI key. Please make sure this is available in plain text under your home directory in ~/.openai.key: {err}")

# Look for the source_documents folder and make sure there is at least 1 pdf file here
contains_pdf = False
documents_path = "./source_documents"
if not os.path.exists(documents_path):
    print(f"ERROR: The {documents_path} subfolder must exist under this notebook")
for filename in os.listdir(documents_path):
    contains_pdf = True if ".pdf" in filename else contains_pdf
if not contains_pdf:
    print(f"ERROR: The {documents_path} subfolder must contain at least one .pdf file")

# %% [markdown]
# ## Generate a sythentic test set

# %% [markdown]
# Start by loading in the documents we'll be using to augment our RAG generations

# %%
loader = PyPDFDirectoryLoader(documents_path)
documents = loader.load()
for document in documents:
    document.metadata['file_name'] = document.metadata['source']

# %% [markdown]
# Now use OpenAI to generate a test set from the data in these documents. This takes 2-3 minutes.

# %%
# Create generator with openai models
generator = TestsetGenerator.with_openai()

# Generate the testset
testset = generator.generate_with_langchain_docs(
    documents, 
    test_size=10, 
    distributions={simple: 0.5, reasoning: 0.25, multi_context: 0.25}
)
# Out:
# embedding nodes:   0%|          | 0/118 [00:00<?, ?it/s]
# Generating:   0%|          | 0/10 [00:00<?, ?it/s]

# %% [markdown]
# Preview the test dataset so far

# %%
testset.to_pandas()
# Out:
#                                             question  \
# 0  What is the mission of the Vector Institute an...
# 1  How does Vector aim to ensure safe and secure ...
# 2  What opportunities are available for AI-skille...
# 3  What skills did participants gain in the Vecto...
# 4  How did the AI Engineering team contribute to ...
# 5  How does the Vector Institute contribute to AI...
# 6  How can the development and scaling of innovat...
# 7  What is the Vector Institute's contribution to...
# 8  How does Vector's leading work in health data ...
# 9  How does the Vector Institute contribute to th...
#
#                                             contexts  \
# 0  [4 \nAnnual Report 2021–22 Vector Institute\n ...
# 1  [ in Vector’s leading work \nin making health ...
# 2  [28 \n MAKING CAREER \nCONNECTIONS FASTER WITH...
# 3  [37 \nAnnual Report 2021–22 Vector Institute\n...
# 4  [36 \n \n \n  CREATING IMPACT \nTHROUGH APPLIC...
# 5  [4 \nAnnual Report 2021–22 Vector Institute\n ...
# 6  [ in Vector’s leading work \nin making health ...
# 7  [24 \nAnnual Report 2021–22 Vector Institute\n...
# 8  [ in Vector’s leading work \nin making health ...
# 9  [4 \nAnnual Report 2021–22 Vector Institute\n ...
#
#                                         ground_truth evolution_type  \
# 0  The mission of the Vector Institute is to lead...         simple
# 1  Vector aims to ensure safe and secure research...         simple
# 2  On Vector's Digital Talent Hub, AI-skilled tal...         simple
# 3  Participants in the Vector bootcamp gained new...         simple
# 4  The AI Engineering team contributed to creatin...         simple
# 5  The Vector Institute contributes to AI-based i...      reasoning
# 6  By fostering practical and enforceable framewo...      reasoning
# 7  The Vector Institute is helping to attract, de...  multi_context
# 8  Vector's leading work in health data accessibi...  multi_context
# 9  The Vector Institute contributes to the growth...      reasoning
#
#    episode_done
# 0          True
# 1          True
# 2          True
# 3          True
# 4          True
# 5          True
# 6          True
# 7          True
# 8          True
# 9          True

# %% [markdown]
# # Now, start the RAG pipeline!

# %% [markdown]
# ## Generate answers for all the questions in our test set

# %% [markdown]
# Go through the embedding, storage and retrieval steps.

# %%
# Split the documents into smaller chunks
text_splitter = RecursiveCharacterTextSplitter(chunk_size=250, chunk_overlap=100)
chunks = text_splitter.split_documents(documents)
print(f"Number of text chunks: {len(chunks)}")

# Define the embeddings model
model_name = "BAAI/bge-small-en-v1.5"
encode_kwargs = {'normalize_embeddings': True} # set True to compute cosine similarity

print(f"Setting up the embeddings model...")
embeddings = OpenAIEmbeddings(model="text-embedding-ada-002")
# Out:
# Number of text chunks: 569
# Setting up the embeddings model...

# %% [markdown]
# Iterate over the questions in our synthetic testset, and run them each through the RAG pipeline to see what answers get returned. (This also takes 2-3 minutes)

# %%
dataset = testset.to_dataset()
answers = np.empty(len(dataset), dtype=object)
llm = ChatOpenAI()

for index, row in enumerate(dataset):
    query = row["question"]
    
    # Retrieve the most relevant context from the vector store based on the query
    vectorstore = FAISS.from_documents(chunks, embeddings)
    retriever = vectorstore.as_retriever(search_kwargs={"k": 20})
    
    # Run the query via our llm (OpenAI) without reranking
    qa = RetrievalQA.from_chain_type(llm=llm,
            chain_type="stuff",
            retriever=retriever)
    answer = qa.run(query=query)
    print(f"Result {index}\nQuestion: {query}\nAnswer: {answer}\n")
   
    # Store the result
    answers[index] = answer
    
    # Let's skip the reranking in this example to keep it fast.
    # Uncomment the following lines to see how reranking will affect the results.
    """
    embeddings = OpenAIEmbeddings()
    embeddings_filter = EmbeddingsFilter(embeddings=embeddings, similarity_threshold=0.76)
    compression_retriever = ContextualCompressionRetriever(
        base_compressor=embeddings_filter, base_retriever=retriever
    )
    compressed_docs = compression_retriever.get_relevant_documents(query)
    
    answer = RetrievalQA.from_chain_type(llm=llm,
        chain_type="stuff",
        retriever=compression_retriever)
        
    dataset[index]["answer"]["answer"] = answer
    print(f"Result:\nQuestion: {query}\nAnswer: {qa.run(query=query)}\n")
    """
# Out:
# /fs01/projects/aieng/public/rag_bootcamp/envs/rag_evaluation/lib/python3.10/site-packages/langchain_core/_api/deprecation.py:117: LangChainDeprecationWarning: The function `run` was deprecated in LangChain 0.1.0 and will be removed in 0.2.0. Use invoke instead.
#   warn_deprecated(
# Result 0
# Question: What is the mission of the Vector Institute and how does it relate to AI-based innovation and deep learning and machine learning?
# Answer: The mission of the Vector Institute is to develop programming for Black and Indigenous students, postdoctoral fellows, and recent graduates to build research opportunities and expand career pathways in AI for historically underrepresented groups. This mission is aimed at fostering diversity and inclusion in the field of AI. Additionally, the institute provides infrastructure and software engineering expertise to support world-leading research, enabling researchers to push the frontiers of AI innovation. Vector also actively contributes expertise and insights on policy issues related to AI adoption to support the best interests of Ontarians and Canadians. Through initiatives like the Smart Health Initiative, Vector is demonstrating the power of machine learning in improving the quality and efficiency of health services. Additionally, Vector is equipping AI professionals to work safely with sensitive data, further advancing AI-based innovation and deep learning and machine learning practices.
#
# Result 1
# Question: How does Vector aim to ensure safe and secure research and application of health data in Canada?
# Answer: Vector aims to ensure safe and secure research and application of health data in Canada by engaging with partners in the health and academic sectors to enable effective, safe, and secure research access to Ontario’s diverse health data. They work on building trust in safe and secure frameworks for health data research and analyses, developing modern data governance frameworks, policies, and processes to guide the safe use of data, and providing skill development programs for AI professionals to work safely with sensitive data. Additionally, Vector works on establishing and expanding agreements with hospitals, clinical research institutes, and related health sector partners to build capacity to apply AI and machine learning for better patient outcomes and system improvements in Canada's health sector.
#
# Result 2
# Question: What opportunities are available for AI-skilled talent on Vector's Digital Talent Hub, and how does the AI Summit and Career Fair contribute to career advancement in the field of AI?
# Answer: Opportunities available for AI-skilled talent on Vector's Digital Talent Hub include access to AI-specific career support programs, events, job postings, and connections with top employers in Ontario looking for AI-skilled talent. The Digital Talent Hub serves as a platform for AI-related internships and work opportunities, with a growing pool of AI-skilled talent actively seeking job opportunities.
#
# The AI Summit and Career Fair organized by Vector Institute provide a significant contribution to career advancement in the field of AI by connecting top talent with leading industry sponsors and employers. At the event, participants can gain insights from industry and research leaders, develop use cases, receive guidance on deploying AI solutions, and explore the implications of AI for business, policy, and ethics. Additionally, the Career Fair offers networking opportunities and direct engagement with employers looking to hire AI-skilled professionals, leading to positive hiring outcomes that transform Ontario's economy.
#
# Result 3
# Question: What skills did participants gain in the Vector bootcamp regarding Privacy Enhancing Technologies (PETs) and how are these technologies applied to working with sensitive data?
# Answer: Participants in the Vector bootcamp on Privacy Enhancing Technologies (PETs) gained new skills in techniques such as differential privacy, homomorphic encryption, and multi-party computation. These skills are crucial in ensuring the privacy and confidentiality of sensitive data while still being able to harness the power of machine and deep learning. By working on use cases that reflect their day-to-day challenges, participants were able to build basic, working PET prototypes and gain hands-on experience in applying PETs to their work with sensitive data.
#
# Result 4
# Question: How did the AI Engineering team contribute to creating impact in AI deployment through their resources?
# Answer: The AI Engineering team contributed to creating impact in AI deployment by providing expertise, upskilling, and hands-on guidance to researchers, industry sponsors, and health partners. They increased the number of full-time resources dedicated to enabling partners and innovation, engaged in real-world projects to accelerate successful AI deployment, collaborated with researchers to share research, and advanced engineering and advocacy to improve governance, privacy, fairness, explainability, security, and anti-bias in AI applications. Additionally, they worked on innovative implementations to deploy AI for forecasting wildfires and improving energy efficiency.
#
# Result 5
# Question: How does the Vector Institute contribute to AI-based innovation in Canada and what is its mission in relation to deep learning and machine learning?
# Answer: The Vector Institute contributes to AI-based innovation in Canada by focusing on developing programming for Black and Indigenous students, postdoctoral fellows, and recent graduates to build research opportunities and expand career pathways in AI for historically underrepresented groups. Its mission in relation to deep learning and machine learning is to lead Ontario’s efforts to build and sustain AI-based innovation, growth, and productivity in Canada by focusing on the transformative potential of deep learning and machine learning. Additionally, Vector equips Canadian businesses to accelerate AI and drive business value through its programming and collaboration opportunities.
#
# Result 6
# Question: How can the development and scaling of innovative technologies in various sectors, including health, finance, and government, be influenced by fostering practical and enforceable frameworks for data storage and protection?
# Answer: By fostering practical and enforceable frameworks for data storage and protection, organizations in various sectors like health, finance, and government can ensure that data is securely stored and accessed. This can lead to increased trust in the use of data, which is essential for the development and scaling of innovative technologies. These frameworks can guide where and how data is stored, who has access to it, and for what purposes, thereby enabling organizations to harness the power of machine learning and deep learning technologies. By creating a culture shift towards modernizing data governance and management, organizations can accelerate AI deployments and unlock transformative benefits in their respective sectors. Additionally, by enabling secure access to data for research and application, organizations can fuel new insights, improve diagnostics, patient care, and overall system performance, leading to advancements in various sectors.
#
# Result 7
# Question: What is the Vector Institute's contribution to the AI-skilled workforce in Ontario and its impact on the province's economy?
# Answer: The Vector Institute plays a significant role in attracting, developing, and connecting AI-skilled workforce in Ontario. They have helped to increase the pool of workforce-ready AI talent in the province, which in turn contributes to Ontario's economic growth. By providing expertise, programming, events, work-integrated learning opportunities, and connecting top talent with leading employers through platforms like the Digital Talent Hub, Vector Institute supports the development of AI talent that is essential for Ontario's position as a world-leading hub of AI talent and investment attraction. Their efforts have led to positive hiring outcomes that are transforming Ontario's economy.
#
# Result 8
# Question: How does Vector's leading work in health data accessibility contribute to safe research, and what initiatives ensure responsible data use in the health sector?
# Answer: Vector's leading work in health data accessibility contributes to safe research by establishing modern data governance frameworks, policies, and processes. These frameworks guide where and how data are stored, protected, and accessed, ensuring that data is used responsibly in research. By providing a safe and trustworthy approach to data, Vector enables the health sector and other industries to scale innovative technologies while contributing data-driven insights to improve outcomes.
#
# Some initiatives that ensure responsible data use in the health sector include:
# 1. Vector's Chief Data Officer role, held by Roxana Sultan, who leads the data strategy to advance modern data governance.
# 2. The Dataset Shift and Potential Remedies Technical Report, a collaborative project with industry sponsors to address data shift challenges.
# 3. Equipping AI professionals with the skills to work safely with sensitive data through upskilling programs and collaborative projects.
# 4. Participation in the Global Partnership on AI to address priorities like data governance and responsible AI.
# 5. Engagement with partners in the health and academic sectors to enable effective, safe, and secure research access to diverse health data.
# 6. Leading AI-enabled research projects across various health areas, ensuring that data is used responsibly and ethically for research purposes.
# Result 9
# Question: How does the Vector Institute contribute to the growth and productivity of Canada by focusing on deep learning and machine learning, and what role does it play in supporting Canadian industry and public institutions in the use of AI?
# Answer: The Vector Institute contributes to the growth and productivity of Canada by focusing on deep learning and machine learning through various initiatives. It provides learning and work experience in these fields to Black and Indigenous students, postdoctoral fellows, recent graduates, and other historically underrepresented groups. By expanding opportunities for talent in Canada, Vector helps in fostering economic growth and improving the lives of Canadians.
#
# Additionally, Vector equips Canadian businesses to accelerate AI adoption and drive business value. It supports organizations in various sectors to apply AI effectively, ultimately strengthening the adoption and application of AI across the Canadian industry. Vector's collaboration with industry sponsors across all sectors helps connect enterprises of all sizes to strengthen and apply AI in Canada, contributing to the country's competitiveness globally.
#
# Furthermore, Vector plays a role in supporting Canadian industry and public institutions in the use of AI by providing expertise and insights on policy issues related to AI adoption. It actively contributes to consultations and presentations on AI's role in economic development, health policy, and responsible AI. By leveraging its deep research expertise, Vector helps organizations apply AI across sectors, securing Ontario’s position as a world-leading hub of AI talent and innovation.

# %% [markdown]
# Add the list of answers into our original dataset. Now we have a complete test set that is ready for evaluation.

# %%
dataset = dataset.add_column("answer", answers)

# %% [markdown]
# ## Evaluate the results

# %%
# Preview the final test set
dataset.to_pandas()
# Out:
#                                             question  \
# 0  What is the mission of the Vector Institute an...
# 1  How does Vector aim to ensure safe and secure ...
# 2  What opportunities are available for AI-skille...
# 3  What skills did participants gain in the Vecto...
# 4  How did the AI Engineering team contribute to ...
# 5  How does the Vector Institute contribute to AI...
# 6  How can the development and scaling of innovat...
# 7  What is the Vector Institute's contribution to...
# 8  How does Vector's leading work in health data ...
# 9  How does the Vector Institute contribute to th...
#
#                                             contexts  \
# 0  [4 \nAnnual Report 2021–22 Vector Institute\n ...
# 1  [ in Vector’s leading work \nin making health ...
# 2  [28 \n MAKING CAREER \nCONNECTIONS FASTER WITH...
# 3  [37 \nAnnual Report 2021–22 Vector Institute\n...
# 4  [36 \n \n \n  CREATING IMPACT \nTHROUGH APPLIC...
# 5  [4 \nAnnual Report 2021–22 Vector Institute\n ...
# 6  [ in Vector’s leading work \nin making health ...
# 7  [24 \nAnnual Report 2021–22 Vector Institute\n...
# 8  [ in Vector’s leading work \nin making health ...
# 9  [4 \nAnnual Report 2021–22 Vector Institute\n ...
#
#                                         ground_truth evolution_type  \
# 0  The mission of the Vector Institute is to lead...         simple
# 1  Vector aims to ensure safe and secure research...         simple
# 2  On Vector's Digital Talent Hub, AI-skilled tal...         simple
# 3  Participants in the Vector bootcamp gained new...         simple
# 4  The AI Engineering team contributed to creatin...         simple
# 5  The Vector Institute contributes to AI-based i...      reasoning
# 6  By fostering practical and enforceable framewo...      reasoning
# 7  The Vector Institute is helping to attract, de...  multi_context
# 8  Vector's leading work in health data accessibi...  multi_context
# 9  The Vector Institute contributes to the growth...      reasoning
#
#    episode_done                                             answer
# 0          True  The mission of the Vector Institute is to deve...
# 1          True  Vector aims to ensure safe and secure research...
# 2          True  Opportunities available for AI-skilled talent ...
# 3          True  Participants in the Vector bootcamp on Privacy...
# 4          True  The AI Engineering team contributed to creatin...
# 5          True  The Vector Institute contributes to AI-based i...
# 6          True  By fostering practical and enforceable framewo...
# 7          True  The Vector Institute plays a significant role ...
# 8          True  Vector's leading work in health data accessibi...
# 9          True  The Vector Institute contributes to the growth...

# %% [markdown]
# Run the evaluation query to score the results. In this evaluation, we are looking at the following metrics:
# - **Faithfulness**: The generated answer is regarded as faithful if all the claims that are made in the answer can be inferred from the given context(s).
# - **Context Precision**: Did our retriever return good results that matched the question it was being asked?
# - **Answer Correctness**: Was the generated answer actually correct? Was it complete?

# %%
score = evaluate(dataset, metrics=[faithfulness,context_precision,answer_correctness])
score.to_pandas()
# Out:
# Evaluating:   0%|          | 0/30 [00:00<?, ?it/s]
#                                             question  \
# 0  What is the mission of the Vector Institute an...
# 1  How does Vector aim to ensure safe and secure ...
# 2  What opportunities are available for AI-skille...
# 3  What skills did participants gain in the Vecto...
# 4  How did the AI Engineering team contribute to ...
# 5  How does the Vector Institute contribute to AI...
# 6  How can the development and scaling of innovat...
# 7  What is the Vector Institute's contribution to...
# 8  How does Vector's leading work in health data ...
# 9  How does the Vector Institute contribute to th...
#
#                                             contexts  \
# 0  [4 \nAnnual Report 2021–22 Vector Institute\n ...
# 1  [ in Vector’s leading work \nin making health ...
# 2  [28 \n MAKING CAREER \nCONNECTIONS FASTER WITH...
# 3  [37 \nAnnual Report 2021–22 Vector Institute\n...
# 4  [36 \n \n \n  CREATING IMPACT \nTHROUGH APPLIC...
# 5  [4 \nAnnual Report 2021–22 Vector Institute\n ...
# 6  [ in Vector’s leading work \nin making health ...
# 7  [24 \nAnnual Report 2021–22 Vector Institute\n...
# 8  [ in Vector’s leading work \nin making health ...
# 9  [4 \nAnnual Report 2021–22 Vector Institute\n ...
#
#                                         ground_truth evolution_type  \
# 0  The mission of the Vector Institute is to lead...         simple
# 1  Vector aims to ensure safe and secure research...         simple
# 2  On Vector's Digital Talent Hub, AI-skilled tal...         simple
# 3  Participants in the Vector bootcamp gained new...         simple
# 4  The AI Engineering team contributed to creatin...         simple
# 5  The Vector Institute contributes to AI-based i...      reasoning
# 6  By fostering practical and enforceable framewo...      reasoning
# 7  The Vector Institute is helping to attract, de...  multi_context
# 8  Vector's leading work in health data accessibi...  multi_context
# 9  The Vector Institute contributes to the growth...      reasoning
#
#    episode_done                                             answer  \
# 0          True  The mission of the Vector Institute is to deve...
# 1          True  Vector aims to ensure safe and secure research...
# 2          True  Opportunities available for AI-skilled talent ...
# 3          True  Participants in the Vector bootcamp on Privacy...
# 4          True  The AI Engineering team contributed to creatin...
# 5          True  The Vector Institute contributes to AI-based i...
# 6          True  By fostering practical and enforceable framewo...
# 7          True  The Vector Institute plays a significant role ...
# 8          True  Vector's leading work in health data accessibi...
# 9          True  The Vector Institute contributes to the growth...
#
#    faithfulness  context_precision  answer_correctness
# 0      0.000000                1.0            0.768787
# 1      1.000000                1.0            0.405552
# 2      0.857143                1.0            0.815894
# 3      1.000000                1.0            0.748630
# 4      0.500000                1.0            0.842657
# 5      0.750000                1.0            0.672653
# 6      1.000000                1.0            0.863141
# 7      1.000000                1.0            0.781068
# 8      0.777778                1.0            0.670394
# 9      0.625000                1.0            0.367064
