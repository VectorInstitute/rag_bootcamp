# %% [markdown]
# # RAG Evaluation Test Set Generation
#
# This example shows how to use the [Ragas](https://github.com/explodinggradients/ragas) framework to generate a **test set** that can be used to evaluate the quality of a RAG pipeline. We then use the Python [langchain](https://python.langchain.com/docs/get_started/introduction) library to run some requests through this pipeline and we evaluate the quality of the results.
#
# **Requirements:**
# - You will need an OpenAI access key, which requires a paid account you can sign up for at https://platform.openai.com/signup.
# - After obtaining this key, store it in plain text in your home in directory in the `~/.openai.key` file.
# - (Optional) Upload some pdf files into the `source_documents` subfolder under this notebook. We have already provided some sample pdfs, but feel free to replace these with your own.

# %% [markdown]
# ## Set up the RAG workflow environment

# %%
from datasets import Dataset 
from getpass import getpass
from langchain.chains import RetrievalQA
from langchain.document_loaders.pdf import PyPDFDirectoryLoader
from langchain.retrievers import ContextualCompressionRetriever
from langchain.retrievers.document_compressors import EmbeddingsFilter
from langchain.schema import HumanMessage
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain_openai import ChatOpenAI, OpenAIEmbeddings
from langchain_community.vectorstores import FAISS
import numpy as np
import os
from pathlib import Path

from ragas import evaluate
from ragas.metrics import faithfulness, answer_correctness, context_precision
from ragas.testset.generator import TestsetGenerator
from ragas.testset.evolutions import simple, reasoning, multi_context

# %% [markdown]
# Set up some helper functions:

# %%
def pretty_print_docs(docs):
    print(
        f"\n{'-' * 100}\n".join(
            [f"Document {i+1}:\n\n" + d.page_content for i, d in enumerate(docs)]
        )
    )

# %% [markdown]
# Make sure other necessary items are in place:

# %%
try:
    os.environ["OPENAI_API_KEY"] = open(Path.home() / ".openai.key", "r").read().strip()
except Exception as err:
    print(f"Could not read your OpenAI key. Please make sure this is available in plain text under your home directory in ~/.openai.key: {err}")

# Look for the source_documents folder and make sure there is at least 1 pdf file here
contains_pdf = False
documents_path = "./source_documents"
if not os.path.exists(documents_path):
    print(f"ERROR: The {documents_path} subfolder must exist under this notebook")
for filename in os.listdir(documents_path):
    contains_pdf = True if ".pdf" in filename else contains_pdf
if not contains_pdf:
    print(f"ERROR: The {documents_path} subfolder must contain at least one .pdf file")

# %% [markdown]
# ## Generate a sythentic test set

# %% [markdown]
# Start by loading in the documents we'll be using to augment our RAG generations

# %%
loader = PyPDFDirectoryLoader(documents_path)
documents = loader.load()
for document in documents:
    document.metadata['file_name'] = document.metadata['source']

# %% [markdown]
# Now use OpenAI to generate a test set from the data in these documents. This takes 2-3 minutes.

# %%
# Create generator with openai models
generator = TestsetGenerator.with_openai()

# Generate the testset
testset = generator.generate_with_langchain_docs(
    documents, 
    test_size=10, 
    distributions={simple: 0.5, reasoning: 0.25, multi_context: 0.25}
)
# Out:
# embedding nodes:   0%|          | 0/118 [00:00<?, ?it/s]
# Generating:   0%|          | 0/10 [00:00<?, ?it/s]
# max retries exceeded for ReasoningEvolution(generator_llm=LangchainLLMWrapper(run_config=RunConfig(timeout=60, max_retries=15, max_wait=90, exception_types=<class 'openai.RateLimitError'>)), docstore=InMemoryDocumentStore(splitter=<langchain.text_splitter.TokenTextSplitter object at 0x7f8794ab4af0>, nodes=[Node(page_content='2021–2022 \nANNUAL \nREPORT ', metadata={'source': 'source_documents/vector-institute-2021-22-annual-report_accessible.pdf', 'page': 0, 'file_name': 'source_documents/vector-institute-2021-22-annual-report_accessible.pdf'}, doc_id='d63297d5-d4f0-477a-b71e-cd1247be7f44', filename='d63297d5-d4f0-477a-b71e-cd1247be7f44'), Node(page_content='2 \n   \n       \n  \n      \n         \n             \n        \n      \n            \n          \n       \n        \n           TABLE OF \nCONTENTS \nMESSAGE FROM THE BOARD \nCHAIR AND THE PRESIDENT & CEO 3 \nVECTOR’S VISION & MISSION 4 \nFIVE YEARS OF AI LEADERSHIP FOR CANADIANS 5 \nONTARIO’S  VIBRANT\nAI ECOSYSTEM 6 \nINDUSTRY INNOVATION 8 RESEARCH & EDUCATION 16 \nTALENT & WORKFORCEDEVELOPMENT     24 \nHEALTH 30 \nAI ENGINEERING 35 \nTHOUGHT LEADERSHIP 38 \nTEAM & LEADERSHIP 40 \nFINANCIALS 41 ', metadata={'source': 'source_documents/vector-institute-2021-22-annual-report_accessible.pdf', 'page': 1, 'file_name': 'source_documents/vector-institute-2021-22-annual-report_accessible.pdf'}, doc_id='1bacbce6-4a72-49d7-b3f0-ef8178829075', filename='1bacbce6-4a72-49d7-b3f0-ef8178829075'), Node(page_content='3 \nMESSAGE FROM \nTHE BOARD CHAIR AND THE PRESIDENT & CEO \nIn the fve short years since Vector was founded, \nartifcial intelligence (AI) has cemented its place as a driver of economic competitiveness and growth. Now more than ever, it can play an important role in our economic recovery from the pandemic. Vector is focused on supporting these goals by leveraging our deep research expertise to help organizations apply AI across sectors, securing Ontario’s position as a world-leading hub of AI talent and investment attraction. While the profound disruption of the COVID pandemic has not yet abated, we remain proud of the Vector community and its shared eforts to enable Canadian industry, health institutions, and governments to unlock a brighter future for all. \nAs we enter the next chapter of Canada’s Pan-\nCanadian AI Strategy (PCAIS), which features a broadened emphasis on commercialization, we are seeing Canada’s bold strategy fourish through the country’s AI ecosystem — built around Vector in Toronto and our counterpart institutes, Amii in Edmonton and Mila in Montreal. We feel the momentum building every day, and we’re not alone: The Brookings Institution recently described Vector as “one of the most ambitious eforts in North America to upgrade a strong ecosystem into a world-class position,” while Forbes published a piece predicting that Toronto will become the most important AI hub in the world outside of Silicon Valley and China. \nGlobal demand for AI talent continues to outpace \nsupply, making it a costly and competitive space. In Toronto, the tech workforce is expanding more quickly than in any other North American city. We can credit Vector’s community as having played a signifcant part in AI’s preeminent role in this growth. \nLast year, almost 1,800 Ontario students began their \nstudies in a Vector-recognized AI-related master’s program or other study paths in AI — both a record number and a 27 per cent increase over the previous year. Last year also saw more than 1,000 new graduates from AI master’s programs in Ontario; a milestone achieved ahead of the province’s 2023 target. These skilled AI graduates will hold an envied role in the workforce of the future. Further, our research community has now grown to more than 700, whose infuence continues to grow; they published more', metadata={'source': 'source_documents/vector-institute-2021-22-annual-report_accessible.pdf', 'page': 2, 'file_name': 'source_documents/vector-institute-2021-22-annual-report_accessi ...

# %% [markdown]
# Preview the test dataset so far

# %%
testset.to_pandas()
# Out:
#                                             question  \
# 0  What is the mission of the Vector Institute an...
# 1  How does Vector aim to ensure safe and secure ...
# 2  What is Vector's Digital Talent Hub and how do...
# 3  How did the addition of full-time AI Engineeri...
# 4  What skills did participants gain in the Vecto...
# 5  How does the Vector Institute contribute to AI...
# 6  How have partnerships and Privacy Enhancing Te...
# 7  How does Vector ensure the safe and secure res...
# 8  Who provides funding for the Vector Institute ...
#
#                                             contexts  \
# 0  [4 \nAnnual Report 2021–22 Vector Institute\n ...
# 1  [ in Vector’s leading work \nin making health ...
# 2  [28 \n MAKING CAREER \nCONNECTIONS FASTER WITH...
# 3  [36 \n \n \n  CREATING IMPACT \nTHROUGH APPLIC...
# 4  [37 \nAnnual Report 2021–22 Vector Institute\n...
# 5  [4 \nAnnual Report 2021–22 Vector Institute\n ...
# 6  [33 \n PARTNERSHIPS FOSTER AN AI-FOR-\nHEALTH ...
# 7  [ in Vector’s leading work \nin making health ...
# 8  [4 \nAnnual Report 2021–22 Vector Institute\n ...
#
#                                         ground_truth evolution_type  \
# 0  The mission of the Vector Institute is to lead...         simple
# 1  Vector aims to ensure safe and secure research...         simple
# 2  Vector's Digital Talent Hub is a platform wher...         simple
# 3  The addition of full-time AI Engineering resou...         simple
# 4  Participants in the Vector bootcamp gained new...         simple
# 5  The Vector Institute contributes to AI-based i...      reasoning
# 6  Partnerships and Privacy Enhancing Technologie...  multi_context
# 7  Vector ensures the safe and secure research an...  multi_context
# 8  The Vector Institute is funded by the Governme...      reasoning
#
#    episode_done
# 0          True
# 1          True
# 2          True
# 3          True
# 4          True
# 5          True
# 6          True
# 7          True
# 8          True

# %% [markdown]
# # Now, start the RAG pipeline!

# %% [markdown]
# ## Generate answers for all the questions in our test set

# %% [markdown]
# Go through the embedding, storage and retrieval steps.

# %%
# Split the documents into smaller chunks
text_splitter = RecursiveCharacterTextSplitter(chunk_size=250, chunk_overlap=100)
chunks = text_splitter.split_documents(documents)
print(f"Number of text chunks: {len(chunks)}")

# Define the embeddings model
model_name = "BAAI/bge-small-en-v1.5"
encode_kwargs = {'normalize_embeddings': True} # set True to compute cosine similarity

print(f"Setting up the embeddings model...")
embeddings = OpenAIEmbeddings(model="text-embedding-ada-002")
# Out:
# Number of text chunks: 569
# Setting up the embeddings model...

# %% [markdown]
# Iterate over the questions in our synthetic testset, and run them each through the RAG pipeline to see what answers get returned. (This also takes 2-3 minutes)

# %%
dataset = testset.to_dataset()
answers = np.empty(len(dataset), dtype=object)
llm = ChatOpenAI()

for index, row in enumerate(dataset):
    query = row["question"]
    
    # Retrieve the most relevant context from the vector store based on the query
    vectorstore = FAISS.from_documents(chunks, embeddings)
    retriever = vectorstore.as_retriever(search_kwargs={"k": 20})
    
    # Run the query via our llm (OpenAI) without reranking
    qa = RetrievalQA.from_chain_type(llm=llm,
            chain_type="stuff",
            retriever=retriever)
    answer = qa.run(query=query)
    print(f"Result {index}\nQuestion: {query}\nAnswer: {answer}\n")
   
    # Store the result
    answers[index] = answer
    
    # Let's skip the reranking in this example to keep it fast.
    # Uncomment the following lines to see how reranking will affect the results.
    """
    embeddings = OpenAIEmbeddings()
    embeddings_filter = EmbeddingsFilter(embeddings=embeddings, similarity_threshold=0.76)
    compression_retriever = ContextualCompressionRetriever(
        base_compressor=embeddings_filter, base_retriever=retriever
    )
    compressed_docs = compression_retriever.get_relevant_documents(query)
    
    answer = RetrievalQA.from_chain_type(llm=llm,
        chain_type="stuff",
        retriever=compression_retriever)
        
    dataset[index]["answer"]["answer"] = answer
    print(f"Result:\nQuestion: {query}\nAnswer: {qa.run(query=query)}\n")
    """
# Out:
# /fs01/projects/aieng/public/rag_bootcamp/envs/rag_evaluation/lib/python3.10/site-packages/langchain_core/_api/deprecation.py:117: LangChainDeprecationWarning: The function `run` was deprecated in LangChain 0.1.0 and will be removed in 0.2.0. Use invoke instead.
#   warn_deprecated(
# Result 0
# Question: What is the mission of the Vector Institute and how does it relate to deep learning and machine learning?
# Answer: The mission of the Vector Institute is to drive excellence and leadership in Canada's knowledge, creation, and use of AI to foster economic growth and improve the lives of Canadians. The institute focuses on advancing the frontiers of AI knowledge, providing education in machine learning, and engineering new frontiers of AI application in various sectors such as industry, health, and government. They work on creating opportunities for research, expanding career pathways, and enabling Black and Indigenous students and professionals to work safely with sensitive data. The institute also collaborates with organizations and partners to apply AI in areas like healthcare to improve services and outcomes.
#
# Result 1
# Question: How does Vector aim to ensure safe and secure research and application of health data in Canada?
# Answer: Vector aims to ensure safe and secure research and application of health data in Canada by engaging with partners in the health and academic sectors. They work on establishing secure frameworks for health data research and analyses. Additionally, they focus on modern data governance frameworks, policies, and processes to guide the safe use of data. Through initiatives like the Smart Health Initiative, they demonstrate the power of machine learning to improve the quality and efficiency of health services in a secure manner. Their efforts include building foundational trust in safe and secure data access models and infrastructure for researchers working with health data.
#
# Result 2
# Question: What is Vector's Digital Talent Hub and how does it connect top talent and employers in Ontario for AI-related internships and work opportunities?
# Answer: Vector's Digital Talent Hub is a platform that facilitates connections between top talent and employers in Ontario specifically for AI-related internships and work opportunities. The hub allows leading industry sponsors to advertise AI-related opportunities to a pool of AI-skilled talent. Employers use the hub to find top AI-skilled talent, and job seekers can access job postings and career support programs and events. Through the hub, recruitment events, and career supports, Vector helps drive positive hiring outcomes that are transforming Ontario's economy by connecting AI researchers, clinicians, and teams from top employers.
#
# Result 3
# Question: How did the addition of full-time AI Engineering resources impact Vector's ability to support industry, health, and government partners in solving AI deployment engineering challenges?
# Answer: The addition of new full-time AI Engineering resources has enabled Vector to provide more direct guidance and deep expertise to industry, health, and government partners in solving AI deployment engineering challenges. This has allowed for better support, collaboration, and upskilling in software, technology, and tools necessary for successful AI deployment.
#
# Result 4
# Question: What skills did participants gain in the Vector bootcamp regarding Privacy Enhancing Technologies (PETs) and how are these technologies important for working with sensitive data?
# Answer: Participants in the Vector bootcamp on Privacy Enhancing Technologies (PETs) gained new skills in techniques such as differential privacy, homomorphic encryption, and multi-party computation. These skills are crucial for working with sensitive data as they help ensure the privacy and confidentiality of the data while still being able to harness the power of machine and deep learning. By learning these PETs, participants are equipped to protect sensitive information while still being able to leverage advanced technologies for data analysis and modeling.
#
# Result 5
# Question: How does the Vector Institute contribute to AI-based innovation in Canada and what is its mission in relation to deep learning and machine learning?
# Answer: The Vector Institute contributes to AI-based innovation in Canada by focusing on developing programming for Black and Indigenous students, postdoctoral fellows, and recent graduates to build research opportunities and expand career pathways in AI for historically underrepresented groups. Their mission in relation to deep learning and machine learning is to lead Ontario’s efforts to build and sustain AI-based innovation, growth, and productivity in Canada by focusing on the transformative potential of deep learning and machine learning. Additionally, Vector equips Canadian businesses to accelerate AI and drive business value, while also providing expertise and insights on policy issues related to AI adoption to support the best interests of Ontarians and Canadians.
#
# Result 6
# Question: How have partnerships and Privacy Enhancing Technologies contributed to Vector's data governance and safe use of health data?
# Answer: Partnerships have played a crucial role in Vector's data governance and safe use of health data by enabling secure access to diverse health data sets for AI-powered research. These partnerships with health institutions, clinical research institutes, and health-related industry partners have facilitated the development of modern data governance frameworks and policies. Additionally, the Privacy Enhancing Technologies (PET) bootcamp has equipped participants with skills to ensure privacy and confidentiality of sensitive patient and clinical data, enhancing the overall safety of data use in research. Through these collaborations and technology initiatives, Vector has been able to drive improvements in health research systems while ensuring the effective, safe, and secure access to Ontario's health data.
#
# Result 7
# Question: How does Vector ensure the safe and secure research and application of health data in Canada, especially with AI integration, and how is trust and expertise built in working with sensitive data?
# Answer: Vector ensures the safe and secure research and application of health data in Canada, particularly with AI integration, through various initiatives. They develop frameworks to improve access to data for AI with a focus on security, privacy, and confidentiality. They also help Ontario hospitals adopt machine learning applications and partner on health data initiatives. Additionally, Vector collaborates with industry, health sectors, and government to equip AI professionals to work safely with sensitive data, providing guidance on deploying AI solutions and exploring the implications of AI for business, policy, and ethics. Trust and expertise are built through Vector's ongoing participation in consultations, presentations, and collaborations at national and international levels, contributing expertise on responsible AI, data governance, and commercialization. By engaging with partners in the health and academic sectors, Vector enables effective, safe, and secure research access to Ontario's diverse health data, driving improvements in health research, systems, and care.
#
# Result 8
# Question: Who provides funding for the Vector Institute and what is their objective in terms of AI innovation and growth in Canada?
# Answer: The Vector Institute is funded by the Government of Canada, the Government of Ontario, as well as industry sponsors from across the Canadian economy. Their objective is to drive excellence and leadership in Canada’s knowledge, creation, and use of AI to foster economic growth and improve the lives of Canadians. They are committed to developing programming for underrepresented groups and expanding career pathways in AI.

# %% [markdown]
# Add the list of answers into our original dataset. Now we have a complete test set that is ready for evaluation.

# %%
dataset = dataset.add_column("answer", answers)

# %% [markdown]
# ## Evaluate the results

# %%
# Preview the final test set
dataset.to_pandas()
# Out:
#                                             question  \
# 0  What is the mission of the Vector Institute an...
# 1  How does Vector aim to ensure safe and secure ...
# 2  What is Vector's Digital Talent Hub and how do...
# 3  How did the addition of full-time AI Engineeri...
# 4  What skills did participants gain in the Vecto...
# 5  How does the Vector Institute contribute to AI...
# 6  How have partnerships and Privacy Enhancing Te...
# 7  How does Vector ensure the safe and secure res...
# 8  Who provides funding for the Vector Institute ...
#
#                                             contexts  \
# 0  [4 \nAnnual Report 2021–22 Vector Institute\n ...
# 1  [ in Vector’s leading work \nin making health ...
# 2  [28 \n MAKING CAREER \nCONNECTIONS FASTER WITH...
# 3  [36 \n \n \n  CREATING IMPACT \nTHROUGH APPLIC...
# 4  [37 \nAnnual Report 2021–22 Vector Institute\n...
# 5  [4 \nAnnual Report 2021–22 Vector Institute\n ...
# 6  [33 \n PARTNERSHIPS FOSTER AN AI-FOR-\nHEALTH ...
# 7  [ in Vector’s leading work \nin making health ...
# 8  [4 \nAnnual Report 2021–22 Vector Institute\n ...
#
#                                         ground_truth evolution_type  \
# 0  The mission of the Vector Institute is to lead...         simple
# 1  Vector aims to ensure safe and secure research...         simple
# 2  Vector's Digital Talent Hub is a platform wher...         simple
# 3  The addition of full-time AI Engineering resou...         simple
# 4  Participants in the Vector bootcamp gained new...         simple
# 5  The Vector Institute contributes to AI-based i...      reasoning
# 6  Partnerships and Privacy Enhancing Technologie...  multi_context
# 7  Vector ensures the safe and secure research an...  multi_context
# 8  The Vector Institute is funded by the Governme...      reasoning
#
#    episode_done                                             answer
# 0          True  The mission of the Vector Institute is to driv...
# 1          True  Vector aims to ensure safe and secure research...
# 2          True  Vector's Digital Talent Hub is a platform that...
# 3          True  The addition of new full-time AI Engineering r...
# 4          True  Participants in the Vector bootcamp on Privacy...
# 5          True  The Vector Institute contributes to AI-based i...
# 6          True  Partnerships have played a crucial role in Vec...
# 7          True  Vector ensures the safe and secure research an...
# 8          True  The Vector Institute is funded by the Governme...

# %% [markdown]
# Run the evaluation query to score the results. In this evaluation, we are looking at the following metrics:
# - **Faithfulness**: The generated answer is regarded as faithful if all the claims that are made in the answer can be inferred from the given context(s).
# - **Context Precision**: Did our retriever return good results that matched the question it was being asked?
# - **Answer Correctness**: Was the generated answer actually correct? Was it complete?

# %%
score = evaluate(dataset, metrics=[faithfulness,context_precision,answer_correctness])
score.to_pandas()
# Out:
# Evaluating:   0%|          | 0/27 [00:00<?, ?it/s]
#                                             question  \
# 0  What is the mission of the Vector Institute an...
# 1  How does Vector aim to ensure safe and secure ...
# 2  What is Vector's Digital Talent Hub and how do...
# 3  How did the addition of full-time AI Engineeri...
# 4  What skills did participants gain in the Vecto...
# 5  How does the Vector Institute contribute to AI...
# 6  How have partnerships and Privacy Enhancing Te...
# 7  How does Vector ensure the safe and secure res...
# 8  Who provides funding for the Vector Institute ...
#
#                                             contexts  \
# 0  [4 \nAnnual Report 2021–22 Vector Institute\n ...
# 1  [ in Vector’s leading work \nin making health ...
# 2  [28 \n MAKING CAREER \nCONNECTIONS FASTER WITH...
# 3  [36 \n \n \n  CREATING IMPACT \nTHROUGH APPLIC...
# 4  [37 \nAnnual Report 2021–22 Vector Institute\n...
# 5  [4 \nAnnual Report 2021–22 Vector Institute\n ...
# 6  [33 \n PARTNERSHIPS FOSTER AN AI-FOR-\nHEALTH ...
# 7  [ in Vector’s leading work \nin making health ...
# 8  [4 \nAnnual Report 2021–22 Vector Institute\n ...
#
#                                         ground_truth evolution_type  \
# 0  The mission of the Vector Institute is to lead...         simple
# 1  Vector aims to ensure safe and secure research...         simple
# 2  Vector's Digital Talent Hub is a platform wher...         simple
# 3  The addition of full-time AI Engineering resou...         simple
# 4  Participants in the Vector bootcamp gained new...         simple
# 5  The Vector Institute contributes to AI-based i...      reasoning
# 6  Partnerships and Privacy Enhancing Technologie...  multi_context
# 7  Vector ensures the safe and secure research an...  multi_context
# 8  The Vector Institute is funded by the Governme...      reasoning
#
#    episode_done                                             answer  \
# 0          True  The mission of the Vector Institute is to driv...
# 1          True  Vector aims to ensure safe and secure research...
# 2          True  Vector's Digital Talent Hub is a platform that...
# 3          True  The addition of new full-time AI Engineering r...
# 4          True  Participants in the Vector bootcamp on Privacy...
# 5          True  The Vector Institute contributes to AI-based i...
# 6          True  Partnerships have played a crucial role in Vec...
# 7          True  Vector ensures the safe and secure research an...
# 8          True  The Vector Institute is funded by the Governme...
#
#    faithfulness  context_precision  answer_correctness
# 0         1.000                1.0            0.786732
# 1         0.800                1.0            0.408247
# 2         1.000                1.0            0.782280
# 3         1.000                1.0            0.621339
# 4         1.000                1.0            0.671530
# 5         0.500                1.0            0.619667
# 6           NaN                1.0            0.651814
# 7         0.875                1.0            0.635263
# 8         0.750                1.0            0.748725
