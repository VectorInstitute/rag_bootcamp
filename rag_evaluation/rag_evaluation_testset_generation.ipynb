# %% [markdown]
# # RAG Evaluation Test Set Generation
#
# This example shows how to use the [Ragas](https://docs.ragas.io/en/stable/) (```v 0.1.22```) framework to generate a **test set** that can be used to evaluate the quality of a RAG pipeline. We then use the Python [LangChain](https://python.langchain.com/docs/introduction/) library to run some requests through this pipeline and we evaluate the quality of the results.
#
# ### <u>Requirements</u>
# 1. As you will accessing the LLMs and embedding models through Vector AI Engineering's Kaleidoscope Service (Vector Inference + Autoscaling), you will need to request a KScope API Key:
#
#       Run the following command (replace ```<user_id>``` and ```<password>```) from **within the cluster** to obtain the API Key. The ```access_token``` in the output is your KScope API Key.
#   ```bash
#   curl -X POST -d "grant_type=password" -d "username=<user_id>" -d "password=<password>" https://kscope.vectorinstitute.ai/token
#   ```
# 2. After obtaining the `.env` configurations, make sure to create the ```.kscope.env``` file in your home directory (```/h/<user_id>```) and set the following env variables:
# - For local models through Kaleidoscope (KScope):
#     ```bash
#     export OPENAI_BASE_URL="https://kscope.vectorinstitute.ai/v1"
#     export OPENAI_API_KEY=<kscope_api_key>
#     ```
# - For OpenAI models:
#    ```bash
#    export OPENAI_BASE_URL="https://api.openai.com/v1"
#    export OPENAI_API_KEY=<openai_api_key>
#    ```

# %% [markdown]
# ## Set up the RAG workflow environment

# %% [markdown]
# #### Import libraries

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import numpy as np
import os
import sys

from datasets import Dataset
from pathlib import Path

from langchain.chains import RetrievalQA
from langchain.document_loaders.pdf import PyPDFDirectoryLoader
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain_community.vectorstores import FAISS
from langchain_huggingface.embeddings import HuggingFaceEmbeddings
from langchain_openai import ChatOpenAI, OpenAIEmbeddings

from ragas import evaluate
from ragas.metrics import Faithfulness, ContextPrecision, AnswerCorrectness
from ragas.testset import TestsetGenerator
from ragas.testset.evolutions import simple, reasoning, multi_context

# %% [markdown]
# #### Load config files

# %%
# Add root folder of the rag_bootcamp repo to PYTHONPATH
current_dir = Path().resolve()
parent_dir = current_dir.parent
sys.path.insert(0, str(parent_dir))

from utils.load_secrets import load_env_file
load_env_file()

# %% [markdown]
# #### Set up some helper functions

# %%
def pretty_print_docs(docs):
    print(
        f"\n{'-' * 100}\n".join(
            [f"Document {i+1}:\n\n" + d.page_content for i, d in enumerate(docs)]
        )
    )

# %% [markdown]
# #### Make sure other necessary items are in place

# %%
# Look for the source_documents folder and make sure there is at least 1 pdf file here
contains_pdf = False
documents_path = "./source_documents"
if not os.path.exists(documents_path):
    print(f"ERROR: The {documents_path} subfolder must exist under this notebook")
for filename in os.listdir(documents_path):
    contains_pdf = True if ".pdf" in filename else contains_pdf
if not contains_pdf:
    print(f"ERROR: The {documents_path} subfolder must contain at least one .pdf file")

# %% [markdown]
# ## Generate a sythentic test set

# %% [markdown]
# #### Start by loading in the documents we'll be using to augment our RAG generations

# %%
loader = PyPDFDirectoryLoader(documents_path)
documents = loader.load()
for document in documents:
    document.metadata['file_name'] = document.metadata['source']

# %% [markdown]
# #### Now use OpenAI to generate a test set from the data in these documents (This takes about 2-3 minutes)

# %% [markdown]
# **IMP Note:** The LLM and embedding model used for test set generation should be more capable than the model being evaluated. Hence, we will use OpenAI GPT-4o and OpenAI embeddings for this purpose.
#
# Store your OpenAI API key in ```~/.ragas_openai.env``` using the following format (this is in addition to ```~/.kscope.env```):
#
# ```bash
# export RAGAS_OPENAI_BASE_URL="https://api.openai.com/v1"
# export RAGAS_OPENAI_API_KEY=<openai_api_key>
# ```

# %%
from utils.load_secrets import load_env_file_ragas
load_env_file_ragas()

# %%
generator_llm = ChatOpenAI(
    model="gpt-4o",
    base_url=os.environ["RAGAS_OPENAI_BASE_URL"],
    api_key=os.environ["RAGAS_OPENAI_API_KEY"],
)
generator_embeddings = OpenAIEmbeddings(
    model="text-embedding-3-small",
    base_url=os.environ["RAGAS_OPENAI_BASE_URL"],
    api_key=os.environ["RAGAS_OPENAI_API_KEY"],
)

# %%
# Create generator with OpenAI model
generator = TestsetGenerator.from_langchain(
    generator_llm=generator_llm,
    critic_llm=generator_llm,
    embeddings=generator_embeddings,
)

# Generate the test set
testset = generator.generate_with_langchain_docs(
    documents=documents, 
    test_size=10,
    distributions={simple: 0.5, reasoning: 0.25, multi_context: 0.25},
)
# Out:
# embedding nodes:   0%|          | 0/86 [00:00<?, ?it/s]
# Filename and doc_id are the same for all nodes.
# Generating:   0%|          | 0/10 [00:00<?, ?it/s]

# %% [markdown]
# #### Preview the test dataset so far

# %%
testset.to_pandas()
# Out:
#                                             question  \
# 0  What is the purpose of the AI for Public Healt...
# 1  What is the purpose of the Vector Faculty Affi...
# 2  What opportunities does the Digital Talent Hub...
# 3  How does Vector Institute integrate responsibl...
# 4  What benefits do scholarship recipients gain f...
# 5                     Who backs Vector's AI efforts?
# 6  How does the Vector Program boost AI expertise...
# 7  How does Vector's work with Ontario's AI scene...
# 8  How does GEMINI's health data integration with...
# 9  What is the purpose of the new Chief Data Offi...
#
#                                             contexts  \
# 0  [33 \n PARTNERSHIPS FOSTER AN AI-FOR-\nHEALTH ...
# 1  [19 \nVECTOR FACULTY \nAFFILIATES \nThe Vector...
# 2  [5 \nAnnual Report 2021–22 Vector Institute\nS...
# 3  [35 \nAnnual Report 2021–22 Vector Institute\n...
# 4  [26 \n  VECTOR SCHOLARSHIPS IN \nAI ATTRACT TO...
# 5  [41 \n \n \n \n \n   FINANCIALS \nVector is fu...
# 6  [19 \nVECTOR FACULTY \nAFFILIATES \nThe Vector...
# 7  [4 \nAnnual Report 2021–22 Vector Institute\n ...
# 8  [31 \n \n \n     NEW DATA SHARING \nAGREEMENTS...
# 9  [33 \n PARTNERSHIPS FOSTER AN AI-FOR-\nHEALTH ...
#
#                                         ground_truth evolution_type  \
# 0  The AI for Public Health (AI4PH) initiative ai...         simple
# 1  The Vector Faculty Affiliates Program brings t...         simple
# 2  The Digital Talent Hub offered 3,700+ postings...         simple
# 3  Vector Institute integrates responsible AI int...         simple
# 4  Scholarship recipients gain access to Vector's...         simple
# 5  Vector's AI efforts are backed by multi-year c...      reasoning
# 6  The Vector Faculty Affiliates Program boosts A...      reasoning
# 7  Vector's work with Ontario's AI scene boosts C...  multi_context
# 8  GEMINI's health data integration with Vector's...  multi_context
# 9  The purpose of the new Chief Data Officer role...         simple
#
#                                             metadata  episode_done
# 0  [{'source': 'source_documents/vector-institute...          True
# 1  [{'source': 'source_documents/vector-institute...          True
# 2  [{'source': 'source_documents/vector-institute...          True
# 3  [{'source': 'source_documents/vector-institute...          True
# 4  [{'source': 'source_documents/vector-institute...          True
# 5  [{'source': 'source_documents/vector-institute...          True
# 6  [{'source': 'source_documents/vector-institute...          True
# 7  [{'source': 'source_documents/vector-institute...          True
# 8  [{'source': 'source_documents/vector-institute...          True
# 9  [{'source': 'source_documents/vector-institute...          True

# %% [markdown]
# ## Now, start the RAG pipeline!

# %% [markdown]
# #### Choose the RAG LLM and embedding model
# Note: This is different than the OpenAI LLM and embedding model defined above for test set generation.

# %%
RAG_LLM_MODEL_NAME = "Meta-Llama-3.1-8B-Instruct"
RAG_EMBEDDING_MODEL_NAME = "BAAI/bge-base-en-v1.5"

# %% [markdown]
# #### Generate answers for all the questions in our test set

# %% [markdown]
# Go through the embedding, storage and retrieval steps.

# %%
# Split the documents into smaller chunks
text_splitter = RecursiveCharacterTextSplitter(chunk_size=256, chunk_overlap=32)
chunks = text_splitter.split_documents(documents)
print(f"Number of text chunks: {len(chunks)}")
# Out:
# Number of text chunks: 486

# %%
# Define the RAG embeddings model (different than the OpenAI embedding model defined above for test set generation)
model_kwargs = {'device': 'cuda', 'trust_remote_code': True}
encode_kwargs = {'normalize_embeddings': True} # set True to compute cosine similarity

print(f"Setting up the RAG embeddings model...")
embeddings = HuggingFaceEmbeddings(
    model_name=RAG_EMBEDDING_MODEL_NAME,
    model_kwargs=model_kwargs,
    encode_kwargs=encode_kwargs,
)
# Out:
# Setting up the RAG embeddings model...

# %%
# Create the vector store and the retriever
vectorstore = FAISS.from_documents(chunks, embeddings)
retriever = vectorstore.as_retriever(search_kwargs={"k": 5})

# %%
# Define the RAG LLM (different than the OpenAI LLM defined above for test set generation)
print(f"Setting up the RAG LLM...")
llm = ChatOpenAI(
    model=RAG_LLM_MODEL_NAME,
    temperature=0,
    max_tokens=256,
    base_url=os.environ["OPENAI_BASE_URL"],
    api_key=os.environ["OPENAI_API_KEY"],
)
# Out:
# Setting up the RAG LLM...

# %% [markdown]
# Iterate over the questions in our synthetic testset, and run them each through the RAG pipeline to see what answers get returned. (This also takes 2-3 minutes)

# %%
dataset = testset.to_dataset()
answers = np.empty(len(dataset), dtype=object)

for index, row in enumerate(dataset):
    query = row["question"]
    
    # Run the query through the RAG pipeline
    rag_pipeline = RetrievalQA.from_llm(
        llm=llm,
        retriever=retriever
    )
    answer = rag_pipeline.invoke(input=query)
    answer = answer["result"]
    print(f"Result {index}\nQuestion: {query}\nAnswer: {answer}\n")
    
    # Store the result
    answers[index] = answer
# Out:
# Result 0
# Question: What is the purpose of the AI for Public Health (AI4PH) initiative launched by Vector?
# Answer: The purpose of the AI for Public Health (AI4PH) initiative launched by Vector is to equip a new generation of public health practitioners with practical skills in AI for public health.
#
# Result 1
# Question: What is the purpose of the Vector Faculty Affiliates Program in expanding expertise in AI and machine learning across Ontario?
# Answer: The Vector Faculty Affiliates Program brings together experts in the field of AI and machine learning to expand expertise in these areas across Ontario.
#
# Result 2
# Question: What opportunities does the Digital Talent Hub offer for AI-focused jobs and internships?
# Answer: According to the context, the Digital Talent Hub offers the following opportunities for AI-focused jobs and internships:
#
# 1. Advertisements for AI-related internships and work opportunities from leading industry sponsors.
# 2. Access to a growing pool of AI-skilled talent.
# 3. Targeted hiring support.
# 4. Curated events.
# 5. A dedicated AI job board.
# 6. Co-hiring top AI talent in select cases.
#
# These opportunities are designed to help top employers find and recruit AI specialists, and to provide job seekers with access to AI-specific career support programs and events.
#
# Result 3
# Question: How does Vector Institute integrate responsible AI into its operations and projects?
# Answer: According to the provided context, Vector Institute integrates responsible AI into its operations and projects through the following means:
#
# 1. Focused on developing and promoting state-of-the-art techniques, technologies, and frameworks that are rooted in deep learning, which suggests a commitment to advancing AI in a responsible manner.
# 2. Guided by experts from Vector's AI Engineering team, who are likely involved in ensuring that AI is developed and applied in a responsible way.
# 3. Participation in the Global Partnership on AI (housed at the OECD), which focuses on priorities including data governance, commercialization, the future of work, responsible AI, and COVID-19. This suggests that Vector Institute is actively engaged in discussions and efforts to promote responsible AI practices.
#
# Overall, it appears that Vector Institute is committed to integrating responsible AI into its operations and projects through a combination of internal expertise and external collaboration.
#
# Result 4
# Question: What benefits do scholarship recipients gain from accessing Vector's Digital Talent Hub?
# Answer: According to the context, scholarship recipients gain the following benefits from accessing Vector's Digital Talent Hub:
#
# 1. Access to AI-focused job postings and internships
# 2. AI-specific career support programs
# 3. Events related to AI careers
#
# These benefits are mentioned in the context as part of the advantages that scholarship recipients gain from being affiliated with Vector.
#
# Result 5
# Question: Who backs Vector's AI efforts?
# Answer: Vector's AI efforts are backed by a team that collaborates with industry, research, and health colleagues at Vector, as well as experts from Vector's AI Engineering.
#
# Result 6
# Question: How does the Vector Program boost AI expertise in Ontario?
# Answer: According to the context, the Vector Program boosts AI expertise in Ontario in the following ways:
#
# 1. Recognizing and awarding AI master's programs and study paths at Ontario universities that are graduating students with the skills and competencies highly sought by industry.
# 2. Helping to attract, develop, and connect the AI-skilled workforce that will transform Ontario's economy.
# 3. Providing funding to Ontario universities to attract the best and brightest students to study in AI-related master's programs through the Vector Institute Scholarship in Artificial Intelligence (VSAI).
# 4. Offering a program that combines technically rigorous content with practical applications and instruction from Vector's leading research, which enables Canadian enterprises to create business value using AI and compete globally.
#
# Overall, the Vector Program aims to build Ontario's AI workforce of the future by recognizing and supporting AI education and research in the province.
#
# Result 7
# Question: How does Vector's work with Ontario's AI scene boost Canada's economy and AI leadership?
# Answer: According to the provided context, Vector's work with Ontario's AI scene boosts Canada's economy and AI leadership in the following ways:
#
# 1. **Establishing Ontario as a global leader in AI**: Vector's efforts have helped cement Ontario's position as a global leader in AI over the past four years, as stated by Hon. Victor Fedeli, Ontario's Minister of Economic Development.
# 2. **Equipping Canadian businesses to accelerate AI and drive business value**: Vector is helping Canadian businesses in all sectors to leverage AI and drive business value, which can lead to increased productivity, competitiveness, and economic growth.
# 3. **Attracting, developing, and connecting the AI-skilled workforce**: Vector is contributing to the development of an AI-skilled workforce in Ontario, which is essential for driving AI-driven innovation and economic growth.
# 4. **Enabling AI-driven innovation**: Vector's work is focused on enabling AI-driven innovation that will enable Canada's economy to thrive in the future.
#
# Overall, Vector's work with Ontario's AI scene is helping to drive economic growth, innovation, and leadership in AI, which can have a positive impact on Canada's economy as a whole.
#
# Result 8
# Question: How does GEMINI's health data integration with Vector's AI boost patient care and efficiency in Ontario hospitals?
# Answer: According to the context, GEMINI's stable and secure data infrastructure and virtual data access model allow Vector to unlock insights from GEMINI data using AI and machine learning, which enables better health outcomes and hospital efficiency. Additionally, the integration of GEMINI data with Vector's AI expertise is helping Ontario hospitals to:
#
# * Reduce costs
# * Improve patient-centred care
# * Refine clinical outcomes
#
# This is made possible by Vector's technical and research expertise, as well as its collaboration with a growing network of health partners.
#
# Result 9
# Question: What is the purpose of the new Chief Data Officer role created by Vector in 2021-22?
# Answer: According to the context, the purpose of the new Chief Data Officer role created by Vector in 2021-22 is to lead Vector's data strategy to advance modern data governance.

# %% [markdown]
# Add the list of answers into our original dataset. Now we have a complete test set that is ready for evaluation.

# %%
dataset = dataset.add_column("answer", answers)

# %% [markdown]
# ## Evaluate the results

# %% [markdown]
# #### Preview the final test set

# %%
dataset.to_pandas()
# Out:
#                                             question  \
# 0  What is the purpose of the AI for Public Healt...
# 1  What is the purpose of the Vector Faculty Affi...
# 2  What opportunities does the Digital Talent Hub...
# 3  How does Vector Institute integrate responsibl...
# 4  What benefits do scholarship recipients gain f...
# 5                     Who backs Vector's AI efforts?
# 6  How does the Vector Program boost AI expertise...
# 7  How does Vector's work with Ontario's AI scene...
# 8  How does GEMINI's health data integration with...
# 9  What is the purpose of the new Chief Data Offi...
#
#                                             contexts  \
# 0  [33 \n PARTNERSHIPS FOSTER AN AI-FOR-\nHEALTH ...
# 1  [19 \nVECTOR FACULTY \nAFFILIATES \nThe Vector...
# 2  [5 \nAnnual Report 2021–22 Vector Institute\nS...
# 3  [35 \nAnnual Report 2021–22 Vector Institute\n...
# 4  [26 \n  VECTOR SCHOLARSHIPS IN \nAI ATTRACT TO...
# 5  [41 \n \n \n \n \n   FINANCIALS \nVector is fu...
# 6  [19 \nVECTOR FACULTY \nAFFILIATES \nThe Vector...
# 7  [4 \nAnnual Report 2021–22 Vector Institute\n ...
# 8  [31 \n \n \n     NEW DATA SHARING \nAGREEMENTS...
# 9  [33 \n PARTNERSHIPS FOSTER AN AI-FOR-\nHEALTH ...
#
#                                         ground_truth evolution_type  \
# 0  The AI for Public Health (AI4PH) initiative ai...         simple
# 1  The Vector Faculty Affiliates Program brings t...         simple
# 2  The Digital Talent Hub offered 3,700+ postings...         simple
# 3  Vector Institute integrates responsible AI int...         simple
# 4  Scholarship recipients gain access to Vector's...         simple
# 5  Vector's AI efforts are backed by multi-year c...      reasoning
# 6  The Vector Faculty Affiliates Program boosts A...      reasoning
# 7  Vector's work with Ontario's AI scene boosts C...  multi_context
# 8  GEMINI's health data integration with Vector's...  multi_context
# 9  The purpose of the new Chief Data Officer role...         simple
#
#                                             metadata  episode_done  \
# 0  [{'file_name': 'source_documents/vector-instit...          True
# 1  [{'file_name': 'source_documents/vector-instit...          True
# 2  [{'file_name': 'source_documents/vector-instit...          True
# 3  [{'file_name': 'source_documents/vector-instit...          True
# 4  [{'file_name': 'source_documents/vector-instit...          True
# 5  [{'file_name': 'source_documents/vector-instit...          True
# 6  [{'file_name': 'source_documents/vector-instit...          True
# 7  [{'file_name': 'source_documents/vector-instit...          True
# 8  [{'file_name': 'source_documents/vector-instit...          True
# 9  [{'file_name': 'source_documents/vector-instit...          True
#
#                                               answer
# 0  The purpose of the AI for Public Health (AI4PH...
# 1  The Vector Faculty Affiliates Program brings t...
# 2  According to the context, the Digital Talent H...
# 3  According to the provided context, Vector Inst...
# 4  According to the context, scholarship recipien...
# 5  Vector's AI efforts are backed by a team that ...
# 6  According to the context, the Vector Program b...
# 7  According to the provided context, Vector's wo...
# 8  According to the context, GEMINI's stable and ...
# 9  According to the context, the purpose of the n...

# %% [markdown]
# Run the evaluation query to score the results. In this evaluation, we are looking at the following metrics:
# - *[Faithfulness](https://docs.ragas.io/en/v0.1.21/concepts/metrics/faithfulness.html)*: Are all the claims that are made in the answer inferred from the given context(s)?
# - *[Context Precision](https://docs.ragas.io/en/v0.1.21/concepts/metrics/context_precision.html)*: Did our retriever return good results that matched the question it was being asked?
# - *[Answer Correctness](https://docs.ragas.io/en/v0.1.21/concepts/metrics/answer_correctness.html)*: Was the generated answer correct? Was it complete?

# %%
score = evaluate(
    dataset=dataset,
    metrics=[
        Faithfulness(),
        ContextPrecision(),
        AnswerCorrectness(),
    ],
    llm=generator_llm, # Using OpenAI LLM as the evaluator
    embeddings=generator_embeddings,
)
score.to_pandas()
# Out:
# Evaluating:   0%|          | 0/30 [00:00<?, ?it/s]
#                                             question  \
# 0  What is the purpose of the AI for Public Healt...
# 1  What is the purpose of the Vector Faculty Affi...
# 2  What opportunities does the Digital Talent Hub...
# 3  How does Vector Institute integrate responsibl...
# 4  What benefits do scholarship recipients gain f...
# 5                     Who backs Vector's AI efforts?
# 6  How does the Vector Program boost AI expertise...
# 7  How does Vector's work with Ontario's AI scene...
# 8  How does GEMINI's health data integration with...
# 9  What is the purpose of the new Chief Data Offi...
#
#                                             contexts  \
# 0  [33 \n PARTNERSHIPS FOSTER AN AI-FOR-\nHEALTH ...
# 1  [19 \nVECTOR FACULTY \nAFFILIATES \nThe Vector...
# 2  [5 \nAnnual Report 2021–22 Vector Institute\nS...
# 3  [35 \nAnnual Report 2021–22 Vector Institute\n...
# 4  [26 \n  VECTOR SCHOLARSHIPS IN \nAI ATTRACT TO...
# 5  [41 \n \n \n \n \n   FINANCIALS \nVector is fu...
# 6  [19 \nVECTOR FACULTY \nAFFILIATES \nThe Vector...
# 7  [4 \nAnnual Report 2021–22 Vector Institute\n ...
# 8  [31 \n \n \n     NEW DATA SHARING \nAGREEMENTS...
# 9  [33 \n PARTNERSHIPS FOSTER AN AI-FOR-\nHEALTH ...
#
#                                         ground_truth evolution_type  \
# 0  The AI for Public Health (AI4PH) initiative ai...         simple
# 1  The Vector Faculty Affiliates Program brings t...         simple
# 2  The Digital Talent Hub offered 3,700+ postings...         simple
# 3  Vector Institute integrates responsible AI int...         simple
# 4  Scholarship recipients gain access to Vector's...         simple
# 5  Vector's AI efforts are backed by multi-year c...      reasoning
# 6  The Vector Faculty Affiliates Program boosts A...      reasoning
# 7  Vector's work with Ontario's AI scene boosts C...  multi_context
# 8  GEMINI's health data integration with Vector's...  multi_context
# 9  The purpose of the new Chief Data Officer role...         simple
#
#                                             metadata  episode_done  \
# 0  [{'file_name': 'source_documents/vector-instit...          True
# 1  [{'file_name': 'source_documents/vector-instit...          True
# 2  [{'file_name': 'source_documents/vector-instit...          True
# 3  [{'file_name': 'source_documents/vector-instit...          True
# 4  [{'file_name': 'source_documents/vector-instit...          True
# 5  [{'file_name': 'source_documents/vector-instit...          True
# 6  [{'file_name': 'source_documents/vector-instit...          True
# 7  [{'file_name': 'source_documents/vector-instit...          True
# 8  [{'file_name': 'source_documents/vector-instit...          True
# 9  [{'file_name': 'source_documents/vector-instit...          True
#
#                                               answer  faithfulness  \
# 0  The purpose of the AI for Public Health (AI4PH...      1.000000
# 1  The Vector Faculty Affiliates Program brings t...      1.000000
# 2  According to the context, the Digital Talent H...      0.100000
# 3  According to the provided context, Vector Inst...      0.545455
# 4  According to the context, scholarship recipien...      1.000000
# 5  Vector's AI efforts are backed by a team that ...      0.000000
# 6  According to the context, the Vector Program b...      0.000000
# 7  According to the provided context, Vector's wo...      0.600000
# 8  According to the context, GEMINI's stable and ...      0.888889
# 9  According to the context, the purpose of the n...      1.000000
#
#    context_precision  answer_correctness
# 0                1.0            0.568036
# 1                1.0            0.610920
# 2                1.0            0.316686
# 3                1.0            0.439291
# 4                1.0            0.217143
# 5                1.0            0.167371
# 6                1.0            0.203814
# 7                1.0            0.412032
# 8                1.0            0.677368
# 9                1.0            0.505192
