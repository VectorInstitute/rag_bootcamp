# %% [markdown]
# # RAG Evaluation Test Set Generation
#
# This example shows how to use the [Ragas](https://github.com/explodinggradients/ragas) framework to generate a **test set** that can be used to evaluate the quality of a RAG pipeline. We then use the Python [langchain](https://python.langchain.com/docs/get_started/introduction) library to run some requests through this pipeline and we evaluate the quality of the results.
#
# **Requirements:**
# - You will need an access key to OpenAI's API key, which you can sign up for at (https://dashboard.cohere.com/welcome/login). A free trial account will suffice, but will be limited to a small number of requests.
# - After obtaining this key, store it in plain text in your home in directory in the `~/.openai.key` file.
# - (Optional) Upload some pdf files into the `source_documents` subfolder under this notebook. We have already provided some sample pdfs, but feel free to replace these with your own.

# %% [markdown]
# ## Set up the RAG workflow environment

# %%
from datasets import Dataset 
from getpass import getpass
from langchain.chains import RetrievalQA
from langchain.document_loaders.pdf import PyPDFDirectoryLoader
from langchain.retrievers import ContextualCompressionRetriever
from langchain.retrievers.document_compressors import EmbeddingsFilter
from langchain.schema import HumanMessage
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain_openai import ChatOpenAI, OpenAIEmbeddings
from langchain_community.vectorstores import FAISS
import numpy as np
import os
from pathlib import Path

from ragas import evaluate
from ragas.metrics import faithfulness, answer_correctness, context_precision
from ragas.testset.generator import TestsetGenerator
from ragas.testset.evolutions import simple, reasoning, multi_context

# %% [markdown]
# Set up some helper functions:

# %%
def pretty_print_docs(docs):
    print(
        f"\n{'-' * 100}\n".join(
            [f"Document {i+1}:\n\n" + d.page_content for i, d in enumerate(docs)]
        )
    )

# %% [markdown]
# Make sure other necessary items are in place:

# %%
try:
    os.environ["OPENAI_API_KEY"] = open(Path.home() / ".openai.key", "r").read().strip()
except Exception as err:
    print(f"Could not read your OpenAI key. Please make sure this is available in plain text under your home directory in ~/.openai.key: {err}")

# Look for the source_documents folder and make sure there is at least 1 pdf file here
contains_pdf = False
documents_path = "./source_documents"
if not os.path.exists(documents_path):
    print(f"ERROR: The {documents_path} subfolder must exist under this notebook")
for filename in os.listdir(documents_path):
    contains_pdf = True if ".pdf" in filename else contains_pdf
if not contains_pdf:
    print(f"ERROR: The {documents_path} subfolder must contain at least one .pdf file")

# %% [markdown]
# ## Generate a sythentic test set

# %% [markdown]
# Start by loading in the documents we'll be using to augment our RAG generations

# %%
loader = PyPDFDirectoryLoader(documents_path)
documents = loader.load()
for document in documents:
    document.metadata['file_name'] = document.metadata['source']

# %% [markdown]
# Now use OpenAI to generate a test set from the data in these documents

# %%
# Create generator with openai models
generator = TestsetGenerator.with_openai()

# Generate the testset
testset = generator.generate_with_langchain_docs(
    documents, 
    test_size=10, 
    distributions={simple: 0.5, reasoning: 0.25, multi_context: 0.25}
)
# Out:
# embedding nodes:   0%|          | 0/118 [00:00<?, ?it/s]
# Generating:   0%|          | 0/10 [00:00<?, ?it/s]

# %% [markdown]
# Add a new column to our testset called "answer". This is where we'll put the answers that our RAG pipeline generates.

# %%
# Preview the dataset
testset.to_pandas()
# Out:
#                                             question  \
# 0  What is the mission of the Vector Institute an...
# 1  How does Vector aim to apply principles of dat...
# 2  What is Vector's Digital Talent Hub and how do...
# 3  How did the addition of full-time AI Engineeri...
# 4  What skills did participants gain in the Vecto...
# 5  How does the Vector Institute contribute to th...
# 6  How have partnerships in the AI-for-health ski...
# 7  "What is the Vector Institute's mission in dee...
# 8  How does Vector's leading work in health data ...
# 9  What is the mission of the Vector Institute an...
#
#                                             contexts  \
# 0  [4 \nAnnual Report 2021–22 Vector Institute\n ...
# 1  [ in Vector’s leading work \nin making health ...
# 2  [28 \n MAKING CAREER \nCONNECTIONS FASTER WITH...
# 3  [36 \n \n \n  CREATING IMPACT \nTHROUGH APPLIC...
# 4  [37 \nAnnual Report 2021–22 Vector Institute\n...
# 5  [4 \nAnnual Report 2021–22 Vector Institute\n ...
# 6  [33 \n PARTNERSHIPS FOSTER AN AI-FOR-\nHEALTH ...
# 7  [4 \nAnnual Report 2021–22 Vector Institute\n ...
# 8  [ in Vector’s leading work \nin making health ...
# 9  [4 \nAnnual Report 2021–22 Vector Institute\n ...
#
#                                         ground_truth evolution_type  \
# 0  The mission of the Vector Institute is to lead...         simple
# 1  Vector aims to apply principles of data storag...         simple
# 2  Vector's Digital Talent Hub is a platform wher...         simple
# 3  The addition of full-time AI Engineering resou...         simple
# 4  Participants in the Vector bootcamp gained new...         simple
# 5  The Vector Institute contributes to the growth...      reasoning
# 6  Partnerships in the AI-for-health skilled comm...      reasoning
# 7  The Vector Institute's mission is to lead Onta...  multi_context
# 8  Vector's leading work in health data accessibi...  multi_context
# 9  The mission of the Vector Institute is to lead...         simple
#
#    episode_done
# 0          True
# 1          True
# 2          True
# 3          True
# 4          True
# 5          True
# 6          True
# 7          True
# 8          True
# 9          True

# %% [markdown]
# # Now, start the RAG pipeline!

# %% [markdown]
# ## Generate answers for all the questions in our test set

# %% [markdown]
# Go through the embedding, storage and retrieval steps.

# %%
# Split the documents into smaller chunks
text_splitter = RecursiveCharacterTextSplitter(chunk_size=250, chunk_overlap=100)
chunks = text_splitter.split_documents(documents)
print(f"Number of text chunks: {len(chunks)}")

# Define the embeddings model
model_name = "BAAI/bge-small-en-v1.5"
encode_kwargs = {'normalize_embeddings': True} # set True to compute cosine similarity

print(f"Setting up the embeddings model...")
embeddings = OpenAIEmbeddings(model="text-embedding-ada-002")
# Out:
# Number of text chunks: 569
# Setting up the embeddings model...

# %% [markdown]
# Iterate over the questions in our synthetic testset, and run them each through the RAG pipeline to see what answers get returned.

# %%
dataset = testset.to_dataset()
answers = np.empty(len(dataset), dtype=object)
llm = ChatOpenAI()

for index, row in enumerate(dataset):
    query = row["question"]
    
    # Retrieve the most relevant context from the vector store based on the query
    vectorstore = FAISS.from_documents(chunks, embeddings)
    retriever = vectorstore.as_retriever(search_kwargs={"k": 20})
    
    # Run the query via our llm (OpenAI) without reranking
    qa = RetrievalQA.from_chain_type(llm=llm,
            chain_type="stuff",
            retriever=retriever)
    answer = qa.run(query=query)
    print(f"Result {index}\nQuestion: {query}\nAnswer: {answer}\n")
   
    # Store the result
    answers[index] = answer
    
    # Let's skip the reranking in this example to keep it fast.
    # Uncomment the following lines to see how reranking will affect the results.
    """
    embeddings = OpenAIEmbeddings()
    embeddings_filter = EmbeddingsFilter(embeddings=embeddings, similarity_threshold=0.76)
    compression_retriever = ContextualCompressionRetriever(
        base_compressor=embeddings_filter, base_retriever=retriever
    )
    compressed_docs = compression_retriever.get_relevant_documents(query)
    
    answer = RetrievalQA.from_chain_type(llm=llm,
        chain_type="stuff",
        retriever=compression_retriever)
        
    dataset[index]["answer"]["answer"] = answer
    print(f"Result:\nQuestion: {query}\nAnswer: {qa.run(query=query)}\n")
    """
# Out:
# /fs01/projects/aieng/public/rag_bootcamp/envs/rag_pubmed_qa/lib/python3.10/site-packages/langchain_core/_api/deprecation.py:117: LangChainDeprecationWarning: The function `run` was deprecated in LangChain 0.1.0 and will be removed in 0.2.0. Use invoke instead.
#   warn_deprecated(
# Result 0
# Question: What is the mission of the Vector Institute and how does it relate to deep learning and machine learning?
# Answer: The mission of the Vector Institute is to drive excellence and leadership in Canada's knowledge, creation, and use of AI to foster economic growth and improve the lives of Canadians. The institute is committed to developing programming for Black and Indigenous students, postdoctoral fellows, and recent graduates to build research opportunities and expand career pathways in AI for historically underrepresented groups. Additionally, Vector is advancing the frontiers of AI knowledge by providing education in machine learning and deep learning concepts, supporting world-class faculty in new discoveries, and engineering new frontiers of AI application in industry, health, and government. They are also working with organizations to equip AI professionals to work safely with sensitive data and actively contributing expertise to policy issues related to AI adoption.
#
# Result 1
# Question: How does Vector aim to apply principles of data storage and protection to ensure safe and secure research and application in Canada, particularly in the context of increasing AI integration across sectors?
# Answer: Vector aims to apply principles of data storage and protection by developing and maintaining essential machine learning computational infrastructure to enable innovation. They focus on enabling Responsible AI and advancing technologies to ensure privacy, fairness, and accountability in AI applications. Additionally, Vector's AI Engineering team works closely with researchers and partners in various sectors to accelerate AI deployments while ensuring safe and secure research access to diverse health data in Ontario. By actively participating in national and international consultations, Vector contributes expertise and recommendations on topics related to AI and its role in economic development and health policy, further promoting safe and secure AI integration across sectors.
#
# Result 2
# Question: What is Vector's Digital Talent Hub and how does it connect top talent and employers in Ontario for AI-related internships and work opportunities?
# Answer: Vector's Digital Talent Hub is a platform where leading industry sponsors advertise AI-related internships and work opportunities to a growing pool of AI-skilled talent. Employers, including top ones, use the hub to find top AI-skilled talent. Through this platform, recruitment events, and career supports, top talent and employers in Ontario are connecting more than ever before. The hub, along with career fairs and other workforce-connection opportunities, serves as an ideal venue for attracting top AI talent to companies. Additionally, Vector offers programming, events, and work-integrated learning opportunities that help students develop the technical and career skills needed to join Ontario's workforce.
#
# Result 3
# Question: How did the addition of full-time AI Engineering resources impact Vector's ability to support industry, health, and government partners in solving AI deployment engineering challenges?
# Answer: The addition of new full-time AI Engineering resources at Vector has enabled more of Vector’s industry, health, and government partners to access deep expertise and direct guidance in solving AI deployment engineering challenges. This has allowed for more engagement, upskilling, and support in software, technology, and tools necessary for successful AI deployment.
#
# Result 4
# Question: What skills did participants gain in the Vector bootcamp regarding Privacy Enhancing Technologies (PETs) and how are these technologies important for working with sensitive data?
# Answer: Participants in the Vector bootcamp regarding Privacy Enhancing Technologies (PETs) gained skills in Privacy Enhancing Techniques (PETs) such as differential privacy, homomorphic encryption, and multi-party computation. These technologies are crucial for ensuring the privacy and confidentiality of sensitive data while harnessing the power of machine and deep learning. By learning these PETs, participants were able to build a basic, working PET prototype and gain hands-on experience in applying PETs to their work with sensitive data. This skill set is essential for those working with financial, health-related, industrial, or government data as it allows them to protect the privacy of the data while still utilizing advanced technologies like machine learning.
#
# Result 5
# Question: How does the Vector Institute contribute to the growth and use of AI in Canada, specifically in the areas of deep learning and machine learning?
# Answer: The Vector Institute contributes to the growth and use of AI in Canada by providing learning and work experiences in machine learning and AI, expanding opportunities for Black and Indigenous talent in the field, collaborating with industry sponsors to strengthen the application of AI in various sectors, conducting cutting-edge research in deep learning and machine learning, and developing programming for historically underrepresented groups to build research opportunities and expand career pathways in AI. Additionally, Vector Institute provides infrastructure and software engineering expertise to support world-leading research in AI innovation.
#
# Result 6
# Question: How have partnerships in the AI-for-health skilled community contributed to the development and implementation of Privacy Enhancing Technologies, as mentioned in the context?
# Answer: Partnerships in the AI-for-health skilled community have contributed to the development and implementation of Privacy Enhancing Technologies (PET) by collaborating on building PET models to apply to their work with sensitive patient and clinical data. Through initiatives like the PET bootcamp, participants from industry, research, and health teams developed a new understanding of PETs, crucial elements in ensuring privacy and confidentiality of sensitive data while harnessing the power of machine and deep learning. These partnerships have enabled secure access to health datasets for AI-powered research, which can improve diagnostics, patient care, and health system performance. Additionally, these collaborations have facilitated engagements, live demonstrations, and upskilling in software, technology, and tools that enable successful AI applications in healthcare.
#
# Result 7
# Question: "What is the Vector Institute's mission in deep learning and machine learning, and how does it contribute to Canada's AI innovation and economic growth?"
# Answer: The Vector Institute's mission in deep learning and machine learning is to lead Ontario’s efforts in building and sustaining AI-based innovation, growth, and productivity in Canada. It focuses on the transformative potential of deep learning and machine learning. By doing so, the Vector Institute contributes to Canada's AI innovation and economic growth by driving excellence and leadership in the country's knowledge, creation, and use of AI. It also enables Canadian enterprises to create business value using AI, equipping them to compete globally and retain top talent. Additionally, by providing opportunities for Black and Indigenous talent in Canada, the Vector Institute expands and accelerates opportunities in AI for historically underrepresented groups, contributing to a more diverse and inclusive AI ecosystem that drives economic growth.
#
# Result 8
# Question: How does Vector's leading work in health data accessibility contribute to safe and secure research, and what initiatives ensure responsible data use in the health sector?
# Answer: Vector's leading work in health data accessibility contributes to safe and secure research by establishing modern data governance frameworks, policies, and processes. By guiding the safe use of data, Vector ensures that health data is accessed and utilized in a responsible manner. Initiatives such as the creation of a Chief Data Officer role, engaging with partners in the health and academic sectors, participating in consultations on AI and health policy, and implementing industry sponsor initiatives like the My Health Data Path data literacy program and the EndALS Kaggle challenge, all contribute to responsible data use in the health sector. Additionally, through collaborations, research projects, and upskilling programs, Vector is equipping AI professionals to work safely with sensitive health data, ultimately promoting trustworthy and ethical practices in health data research and analysis.
# Result 9
# Question: What is the mission of the Vector Institute and how does it contribute to AI-based innovation in Canada?
# Answer: The mission of the Vector Institute is to develop programming for Black and Indigenous students, postdoctoral fellows, and recent graduates to build research opportunities and expand career pathways in AI for historically underrepresented groups. The institute also contributes to AI-based innovation in Canada by equipping Canadian businesses to accelerate AI adoption, driving business value, and fostering a dynamic AI ecosystem for industry, health, innovation, and advanced research. Additionally, Vector actively contributes expertise and insights on policy issues related to AI adoption to support the best interests of Ontarians and Canadians.

# %% [markdown]
# Add the list of answers into our original dataset. Now we have a complete test set that is ready for evaluation.

# %%
dataset = dataset.add_column("answer", answers)

# %% [markdown]
# ## Evaluate the results

# %%
# Preview the final dataset
dataset.to_pandas()
# Out:
#                                             question  \
# 0  What is the mission of the Vector Institute an...
# 1  How does Vector aim to apply principles of dat...
# 2  What is Vector's Digital Talent Hub and how do...
# 3  How did the addition of full-time AI Engineeri...
# 4  What skills did participants gain in the Vecto...
# 5  How does the Vector Institute contribute to th...
# 6  How have partnerships in the AI-for-health ski...
# 7  "What is the Vector Institute's mission in dee...
# 8  How does Vector's leading work in health data ...
# 9  What is the mission of the Vector Institute an...
#
#                                             contexts  \
# 0  [4 \nAnnual Report 2021–22 Vector Institute\n ...
# 1  [ in Vector’s leading work \nin making health ...
# 2  [28 \n MAKING CAREER \nCONNECTIONS FASTER WITH...
# 3  [36 \n \n \n  CREATING IMPACT \nTHROUGH APPLIC...
# 4  [37 \nAnnual Report 2021–22 Vector Institute\n...
# 5  [4 \nAnnual Report 2021–22 Vector Institute\n ...
# 6  [33 \n PARTNERSHIPS FOSTER AN AI-FOR-\nHEALTH ...
# 7  [4 \nAnnual Report 2021–22 Vector Institute\n ...
# 8  [ in Vector’s leading work \nin making health ...
# 9  [4 \nAnnual Report 2021–22 Vector Institute\n ...
#
#                                         ground_truth evolution_type  \
# 0  The mission of the Vector Institute is to lead...         simple
# 1  Vector aims to apply principles of data storag...         simple
# 2  Vector's Digital Talent Hub is a platform wher...         simple
# 3  The addition of full-time AI Engineering resou...         simple
# 4  Participants in the Vector bootcamp gained new...         simple
# 5  The Vector Institute contributes to the growth...      reasoning
# 6  Partnerships in the AI-for-health skilled comm...      reasoning
# 7  The Vector Institute's mission is to lead Onta...  multi_context
# 8  Vector's leading work in health data accessibi...  multi_context
# 9  The mission of the Vector Institute is to lead...         simple
#
#    episode_done                                             answer
# 0          True  The mission of the Vector Institute is to driv...
# 1          True  Vector aims to apply principles of data storag...
# 2          True  Vector's Digital Talent Hub is a platform wher...
# 3          True  The addition of new full-time AI Engineering r...
# 4          True  Participants in the Vector bootcamp regarding ...
# 5          True  The Vector Institute contributes to the growth...
# 6          True  Partnerships in the AI-for-health skilled comm...
# 7          True  The Vector Institute's mission in deep learnin...
# 8          True  Vector's leading work in health data accessibi...
# 9          True  The mission of the Vector Institute is to deve...

# %% [markdown]
# Run the evaluation query to score the results. In this evaluation, we are looking at the following metrics:
# - **Faithfulness**: The generated answer is regarded as faithful if all the claims that are made in the answer can be inferred from the given context(s).
# - **Context Precision**: Did our retriever return good results that matched the question it was being asked?
# - **Answer Correctness**: Was the generated answer actually correct? Was it complete?

# %%
score = evaluate(dataset, metrics=[faithfulness,context_precision,answer_correctness])
score.to_pandas()
# Out:
# Evaluating:   0%|          | 0/30 [00:00<?, ?it/s]
#                                             question  \
# 0  What is the mission of the Vector Institute an...
# 1  How does Vector aim to apply principles of dat...
# 2  What is Vector's Digital Talent Hub and how do...
# 3  How did the addition of full-time AI Engineeri...
# 4  What skills did participants gain in the Vecto...
# 5  How does the Vector Institute contribute to th...
# 6  How have partnerships in the AI-for-health ski...
# 7  "What is the Vector Institute's mission in dee...
# 8  How does Vector's leading work in health data ...
# 9  What is the mission of the Vector Institute an...
#
#                                             contexts  \
# 0  [4 \nAnnual Report 2021–22 Vector Institute\n ...
# 1  [ in Vector’s leading work \nin making health ...
# 2  [28 \n MAKING CAREER \nCONNECTIONS FASTER WITH...
# 3  [36 \n \n \n  CREATING IMPACT \nTHROUGH APPLIC...
# 4  [37 \nAnnual Report 2021–22 Vector Institute\n...
# 5  [4 \nAnnual Report 2021–22 Vector Institute\n ...
# 6  [33 \n PARTNERSHIPS FOSTER AN AI-FOR-\nHEALTH ...
# 7  [4 \nAnnual Report 2021–22 Vector Institute\n ...
# 8  [ in Vector’s leading work \nin making health ...
# 9  [4 \nAnnual Report 2021–22 Vector Institute\n ...
#
#                                         ground_truth evolution_type  \
# 0  The mission of the Vector Institute is to lead...         simple
# 1  Vector aims to apply principles of data storag...         simple
# 2  Vector's Digital Talent Hub is a platform wher...         simple
# 3  The addition of full-time AI Engineering resou...         simple
# 4  Participants in the Vector bootcamp gained new...         simple
# 5  The Vector Institute contributes to the growth...      reasoning
# 6  Partnerships in the AI-for-health skilled comm...      reasoning
# 7  The Vector Institute's mission is to lead Onta...  multi_context
# 8  Vector's leading work in health data accessibi...  multi_context
# 9  The mission of the Vector Institute is to lead...         simple
#
#    episode_done                                             answer  \
# 0          True  The mission of the Vector Institute is to driv...
# 1          True  Vector aims to apply principles of data storag...
# 2          True  Vector's Digital Talent Hub is a platform wher...
# 3          True  The addition of new full-time AI Engineering r...
# 4          True  Participants in the Vector bootcamp regarding ...
# 5          True  The Vector Institute contributes to the growth...
# 6          True  Partnerships in the AI-for-health skilled comm...
# 7          True  The Vector Institute's mission in deep learnin...
# 8          True  Vector's leading work in health data accessibi...
# 9          True  The mission of the Vector Institute is to deve...
#
#    faithfulness  context_precision  answer_correctness
# 0      0.375000                1.0            0.786773
# 1      0.714286                1.0            0.416950
# 2      0.600000                1.0            0.395618
# 3      1.000000                1.0            0.620852
# 4      1.000000                1.0            0.843772
# 5      0.500000                1.0            0.357827
# 6      1.000000                1.0            0.431891
# 7      0.666667                1.0            0.747419
# 8      0.714286                1.0            0.574445
# 9      0.500000                1.0            0.648331
